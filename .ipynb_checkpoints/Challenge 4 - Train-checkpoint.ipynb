# %% [markdown]
# # AutoML Training Script
#
# In this notebook, we do data exploration as well as model training
#
# ## Load Data
#
# We begin with loading the data and examining the data available

# %%
import pandas as pd
import numpy as np
import pickle

df = pd.read_csv('AssetData_Historical.csv')#.drop(['Machine_ID', 'Latitude', 'Longitude'], 1) #LongLat not unique with District
df_test = pd.read_csv('AssetData_New.csv').drop(['Machine_ID', 'Latitude', 'Longitude'], 1) #LongLat not unique with District
df.head()
# Out:
#    Machine_ID  Density_Overload  Abnormal_Flow_Rate  Heat_Flow  \
# 0      111436              7877                   2       7879
# 1      185081              7877                   2       7879
# 2      111413              7099                   1       7100
# 3      185070              7099                   1       7100
# 4      111385              7797                   3       7800
#
#    Asset_Integrity  Temperature_Differential  Volumetric_Flow_Rate  \
# 0           783360                      1062                  1576
# 1           783360                      1062                  1576
# 2           783360                       844                  1682
# 3           783360                       844                  1682
# 4           783360                      1029                  1604
#
#    Tangential_Stress  Duct_Lengths_in_Units  Fault_in_last_Month  \
# 0               1716                   1978                    0
# 1               1716                   1978                    0
# 2               1698                   1715                    0
# 3               1698                   1715                    0
# 4               1641                   1880                    0
#
#          ...         Compression_Ratio  Multiple_Connects  \
# 0        ...                         3                785
# 1        ...                         3                785
# 2        ...                         3                722
# 3        ...                         3                722
# 4        ...                         3                836
#
#    Water_Exposure_units  Humidity_Factor  Cathodic_Protection  Pressure_Class  \
# 0                  3139              128                    1               1
# 1                  3139              128                    1               1
# 2                  2874              128                    1               1
# 3                  2874              128                    1               1
# 4                  4831              128                    1               1
#
#             District  Latitude  Longitude  Failure_NextHour
# 0             Rochor      1,31     103,87                 0
# 1       Geylang West      1,32     103,89                 0
# 2        Hume Estate      1,35     103,82                 0
# 3       Little India      1,31     103,85                 0
# 4  Jurong?esidential      1,35     103,82                 1
#
# [5 rows x 26 columns]

# %% [markdown]
# Immediately we realise that the Long/Lat columns are read at strings, particularly with ',' as decimal indicators. We write a simple script to clean the columns into compatible float values.
#
# Furthermore, we see that the District Column matches the Long/Lat columns exactly. The Long/Lat columns potentially contains more information, and District column requires one-hot encoding. We decide to drop District column since it provides no additional information on top of Long/Lat.

# %%
df.drop(['Machine_ID', 'District'], axis=1, inplace=True)

# %%
def cleanLongLat(l):
    split = l.str.split(',', expand=True)
    split = (split[0]+'.'+[i if len(i)>1 else i+'0' for i in split[1]]).astype(float)
    return(split)

df['Latitude'] = cleanLongLat(df['Latitude'])
df['Longitude'] = cleanLongLat(df['Longitude'])

# %%
len(df['Asset_Integrity'].unique())
# Out:
# 50

# %% [markdown]
# Note: We noticed that Asset Integrity only has 50 unique values. It is likely to be referring to categories of asset integrity. However, without any further information, we will leave it as integer values for the purpose of this exercise. More information about the data is required.

# %% [markdown]
# Next, we want to do quick exploration. We begin with finding any missing entries, as well as looking at correlation between predictors and target variable

# %%
df.isnull().sum()
# Out:
# Density_Overload                   0
# Abnormal_Flow_Rate                 0
# Heat_Flow                          0
# Asset_Integrity                    0
# Temperature_Differential           0
# Volumetric_Flow_Rate               0
# Tangential_Stress                  0
# Duct_Lengths_in_Units              0
# Fault_in_last_Month                0
# Avg_hours_in_Use                   0
# Pressure_Alarm                     0
# Inclination_Angle                  0
# Location_Fault_Code                0
# Operating_Pressure_above_Normal    0
# Vandalism_Reports                  0
# Compression_Ratio                  0
# Multiple_Connects                  0
# Water_Exposure_units               0
# Humidity_Factor                    0
# Cathodic_Protection                0
# Pressure_Class                     0
# Latitude                           0
# Longitude                          0
# Failure_NextHour                   0
# dtype: int64

# %%
df.corr()
# Out:
#                                  Density_Overload  Abnormal_Flow_Rate  \
# Density_Overload                         1.000000            0.213953
# Abnormal_Flow_Rate                       0.213953            1.000000
# Heat_Flow                                0.816754            0.172850
# Asset_Integrity                          0.351662           -0.004151
# Temperature_Differential                 0.377343            0.124482
# Volumetric_Flow_Rate                     0.570871            0.003325
# Tangential_Stress                        0.556368            0.008282
# Duct_Lengths_in_Units                    0.430534            0.084355
# Fault_in_last_Month                     -0.220760            0.011510
# Avg_hours_in_Use                         0.577219           -0.000094
# Pressure_Alarm                           0.209107            0.024607
# Inclination_Angle                        0.474311            0.039676
# Location_Fault_Code                      0.604754            0.050702
# Operating_Pressure_above_Normal          0.345853           -0.002889
# Vandalism_Reports                        0.193853            0.043134
# Compression_Ratio                        0.679247            0.087553
# Multiple_Connects                        0.820239            0.144965
# Water_Exposure_units                     0.908305            0.218419
# Humidity_Factor                          0.506550            0.036166
# Cathodic_Protection                     -0.351434           -0.096641
# Pressure_Class                           0.408092            0.106887
# Latitude                                -0.010312           -0.004386
# Longitude                               -0.004230            0.010395
# Failure_NextHour                        -0.087024           -0.021901
#
#                                  Heat_Flow  Asset_Integrity  \
# Density_Overload                  0.816754         0.351662
# Abnormal_Flow_Rate                0.172850        -0.004151
# Heat_Flow                         1.000000         0.530835
# Asset_Integrity                   0.530835         1.000000
# Temperature_Differential          0.465880         0.258145
# Volumetric_Flow_Rate              0.740692         0.258186
# Tangential_Stress                 0.724796         0.237170
# Duct_Lengths_in_Units             0.587358         0.119656
# Fault_in_last_Month              -0.201193        -0.372188
# Avg_hours_in_Use                  0.744314         0.276150
# Pressure_Alarm                    0.278216         0.065104
# Inclination_Angle                 0.632748         0.223164
# Location_Fault_Code               0.570373         0.427324
# Operating_Pressure_above_Normal   0.481982         0.142548
# Vandalism_Reports                 0.177770         0.056072
# Compression_Ratio                 0.632241         0.622167
# Multiple_Connects                 0.801082         0.298326
# Water_Exposure_units              0.788693         0.292916
# Humidity_Factor                   0.483371         0.911570
# Cathodic_Protection               0.132709         0.248745
# Pressure_Class                    0.336258         0.031216
# Latitude                         -0.014915        -0.011228
# Longitude                        -0.002667         0.002324
# Failure_NextHour                 -0.053134         0.046219
#
#                                  Temperature_Differential  \
# Density_Overload                                 0.377343
# Abnormal_Flow_Rate                               0.124482
# Heat_Flow                                        0.465880
# Asset_Integrity                                  0.258145
# Temperature_Differential                         1.000000
# Volumetric_Flow_Rate                             0.183473
# Tangential_Stress                                0.186437
# Duct_Lengths_in_Units                            0.382701
# Fault_in_last_Month                             -0.074888
# Avg_hours_in_Use                                 0.158436
# Pressure_Alarm                                   0.161712
# Inclination_Angle                                0.240396
# Location_Fault_Code                              0.243451
# Operating_Pressure_above_Normal                  0.170019
# Vandalism_Reports                                0.085021
# Compression_Ratio                                0.328921
# Multiple_Connects                                0.474112
# Water_Exposure_units                             0.517217
# Humidity_Factor                                  0.234152
# Cathodic_Protection                              0.066515
# Pressure_Class                                   0.210291
# Latitude                                        -0.009762
# Longitude                                        0.000105
# Failure_NextHour                                -0.060799
#
#                                  Volumetric_Flow_Rate  Tangential_Stress  \
# Density_Overload                             0.570871           0.556368
# Abnormal_Flow_Rate                           0.003325           0.008282
# Heat_Flow                                    0.740692           0.724796
# Asset_Integrity                              0.258186           0.237170
# Temperature_Differential                     0.183473           0.186437
# Volumetric_Flow_Rate                         1.000000           0.990529
# Tangential_Stress                            0.990529           1.000000
# Duct_Lengths_in_Units                        0.657269           0.681816
# Fault_in_last_Month                         -0.165331          -0.162114
# Avg_hours_in_Use                             0.985292           0.972280
# Pressure_Alarm                               0.356466           0.358604
# Inclination_Angle                            0.794028           0.796678
# Location_Fault_Code                          0.481414           0.471725
# Operating_Pressure_above_Normal              0.744896           0.776051
# Vandalism_Reports                            0.107318           0.122956
# Compression_Ratio                            0.411663           0.396725
# Multiple_Connects                            0.567000           0.560576
# Water_Exposure_units                         0.487839           0.480895
# Humidity_Factor                              0.187735           0.166028
# Cathodic_Protection                          0.176347           0.177116
# Pressure_Class                               0.361949           0.365949
# Latitude                                    -0.012698          -0.013039
# Longitude                                   -0.005900          -0.005754
# Failure_NextHour                            -0.099991          -0.105457
#
#                                  Duct_Lengths_in_Units  Fault_in_last_Month  \
# Density_Overload                              0.430534            -0.220760
# Abnormal_Flow_Rate                            0.084355             0.011510
# Heat_Flow                                     0.587358            -0.201193
# Asset_Integrity                               0.119656            -0.372188
# Temperature_Differential                      0.382701            -0.074888
# Volumetric_Flow_Rate                          0.657269            -0.165331
# Tangential_Stress                             0.681816            -0.162114
# Duct_Lengths_in_Units                         1.000000            -0.136521
# Fault_in_last_Month                          -0.136521             1.000000
# Avg_hours_in_Use                              0.590984            -0.161808
# Pressure_Alarm                                0.401551            -0.037736
# Inclination_Angle                             0.643713            -0.157304
# Location_Fault_Code                           0.218514            -0.212958
# Operating_Pressure_above_Normal               0.669222            -0.175663
# Vandalism_Reports                             0.063613            -0.038184
# Compression_Ratio                             0.221804            -0.301645
# Multiple_Connects                             0.490976            -0.151786
# Water_Exposure_units                          0.485157            -0.161859
# Humidity_Factor                               0.043847            -0.417224
# Cathodic_Protection                           0.183283             0.091157
# Pressure_Class                                0.377411            -0.057409
# Latitude                                     -0.017280            -0.000137
# Longitude                                    -0.004431             0.002422
# Failure_NextHour                             -0.181797             0.021366
#
#                                  Avg_hours_in_Use        ...         \
# Density_Overload                         0.577219        ...
# Abnormal_Flow_Rate                      -0.000094        ...
# Heat_Flow                                0.744314        ...
# Asset_Integrity                          0.276150        ...
# Temperature_Differential                 0.158436        ...
# Volumetric_Flow_Rate                     0.985292        ...
# Tangential_Stress                        0.972280        ...
# Duct_Lengths_in_Units                    0.590984        ...
# Fault_in_last_Month                     -0.161808        ...
# Avg_hours_in_Use                         1.000000        ...
# Pressure_Alarm                           0.327133        ...
# Inclination_Angle                        0.784621        ...
# Location_Fault_Code                      0.479023        ...
# Operating_Pressure_above_Normal          0.684991        ...
# Vandalism_Reports                        0.106568        ...
# Compression_Ratio                        0.417957        ...
# Multiple_Connects                        0.563756        ...
# Water_Exposure_units                     0.478507        ...
# Humidity_Factor                          0.208780        ...
# Cathodic_Protection                      0.169817        ...
# Pressure_Class                           0.338580        ...
# Latitude                                -0.012246        ...
# Longitude                               -0.006712        ...
# Failure_NextHour                        -0.084762        ...
#
#                                  Vandalism_Reports  Compression_Ratio  \
# Density_Overload                          0.193853           0.679247
# Abnormal_Flow_Rate                        0.043134           0.087553
# Heat_Flow                                 0.177770           0.632241
# Asset_Integrity                           0.056072           0.622167
# Temperature_Differential                  0.085021           0.328921
# Volumetric_Flow_Rate                      0.107318           0.411663
# Tangential_Stress                         0.122956           0.396725
# Duct_Lengths_in_Units                     0.063613           0.221804
# Fault_in_last_Month                      -0.038184          -0.301645
# Avg_hours_in_Use                          0.106568           0.417957
# Pressure_Alarm                            0.070162           0.156199
# Inclination_Angle                         0.097147           0.334078
# Location_Fault_Code                       0.543504           0.793386
# Operating_Pressure_above_Normal           0.049842           0.243430
# Vandalism_Reports                         1.000000           0.364533
# Compression_Ratio                         0.364533           1.000000
# Multiple_Connects                         0.358372           0.663890
# Water_Exposure_units                      0.249677           0.658881
# Humidity_Factor                           0.080323           0.717192
# Cathodic_Protection                      -0.055145          -0.198991
# Pressure_Class                            0.168251           0.304457
# Latitude                                  0.003696          -0.009476
# Longitude                                -0.002693          -0.006248
# Failure_NextHour                         -0.030911          -0.082738
#
#                                  Multiple_Connects  Water_Exposure_units  \
# Density_Overload                          0.820239              0.908305
# Abnormal_Flow_Rate                        0.144965              0.218419
# Heat_Flow                                 0.801082              0.788693
# Asset_Integrity                           0.298326              0.292916
# Temperature_Differential                  0.474112              0.517217
# Volumetric_Flow_Rate                      0.567000              0.487839
# Tangential_Stress                         0.560576              0.480895
# Duct_Lengths_in_Units                     0.490976              0.485157
# Fault_in_last_Month                      -0.151786             -0.161859
# Avg_hours_in_Use                          0.563756              0.478507
# Pressure_Alarm                            0.286395              0.257043
# Inclination_Angle                         0.506151              0.471435
# Location_Fault_Code                       0.624410              0.577725
# Operating_Pressure_above_Normal           0.352468              0.320423
# Vandalism_Reports                         0.358372              0.249677
# Compression_Ratio                         0.663890              0.658881
# Multiple_Connects                         1.000000              0.905253
# Water_Exposure_units                      0.905253              1.000000
# Humidity_Factor                           0.369289              0.419353
# Cathodic_Protection                      -0.155732             -0.287003
# Pressure_Class                            0.424383              0.435236
# Latitude                                 -0.012404             -0.010432
# Longitude                                -0.003114             -0.001526
# Failure_NextHour                         -0.084792             -0.088829
#
#                                  Humidity_Factor  Cathodic_Protection  \
# Density_Overload                        0.506550            -0.351434
# Abnormal_Flow_Rate                      0.036166            -0.096641
# Heat_Flow                               0.483371             0.132709
# Asset_Integrity                         0.911570             0.248745
# Temperature_Differential                0.234152             0.066515
# Volumetric_Flow_Rate                    0.187735             0.176347
# Tangential_Stress                       0.166028             0.177116
# Duct_Lengths_in_Units                   0.043847             0.183283
# Fault_in_last_Month                    -0.417224             0.091157
# Avg_hours_in_Use                        0.208780             0.169817
# Pressure_Alarm                          0.033792             0.076367
# Inclination_Angle                       0.151664             0.177373
# Location_Fault_Code                     0.493440            -0.138646
# Operating_Pressure_above_Normal         0.073082             0.169438
# Vandalism_Reports                       0.080323            -0.055145
# Compression_Ratio                       0.717192            -0.198991
# Multiple_Connects                       0.369289            -0.155732
# Water_Exposure_units                    0.419353            -0.287003
# Humidity_Factor                         1.000000            -0.171319
# Cathodic_Protection                    -0.171319             1.000000
# Pressure_Class                          0.100191            -0.161861
# Latitude                               -0.006013            -0.012933
# Longitude                              -0.000728             0.007185
# Failure_NextHour                        0.013853             0.078179
#
#                                  Pressure_Class  Latitude  Longitude  \
# Density_Overload                       0.408092 -0.010312  -0.004230
# Abnormal_Flow_Rate                     0.106887 -0.004386   0.010395
# Heat_Flow                              0.336258 -0.014915  -0.002667
# Asset_Integrity                        0.031216 -0.011228   0.002324
# Temperature_Differential               0.210291 -0.009762   0.000105
# Volumetric_Flow_Rate                   0.361949 -0.012698  -0.005900
# Tangential_Stress                      0.365949 -0.013039  -0.005754
# Duct_Lengths_in_Units                  0.377411 -0.017280  -0.004431
# Fault_in_last_Month                   -0.057409 -0.000137   0.002422
# Avg_hours_in_Use                       0.338580 -0.012246  -0.006712
# Pressure_Alarm                         0.711562 -0.005250   0.006143
# Inclination_Angle                      0.336392 -0.015071  -0.003345
# Location_Fault_Code                    0.309484 -0.010044  -0.003759
# Operating_Pressure_above_Normal        0.311583 -0.010180  -0.002810
# Vandalism_Reports                      0.168251  0.003696  -0.002693
# Compression_Ratio                      0.304457 -0.009476  -0.006248
# Multiple_Connects                      0.424383 -0.012404  -0.003114
# Water_Exposure_units                   0.435236 -0.010432  -0.001526
# Humidity_Factor                        0.100191 -0.006013  -0.000728
# Cathodic_Protection                   -0.161861 -0.012933   0.007185
# Pressure_Class                         1.000000 -0.001657  -0.001899
# Latitude                              -0.001657  1.000000   0.054408
# Longitude                             -0.001899  0.054408   1.000000
# Failure_NextHour                      -0.136602 -0.006237   0.010086
#
#                                  Failure_NextHour
# Density_Overload                        -0.087024
# Abnormal_Flow_Rate                      -0.021901
# Heat_Flow                               -0.053134
# Asset_Integrity                          0.046219
# Temperature_Differential                -0.060799
# Volumetric_Flow_Rate                    -0.099991
# Tangential_Stress                       -0.105457
# Duct_Lengths_in_Units                   -0.181797
# Fault_in_last_Month                      0.021366
# Avg_hours_in_Use                        -0.084762
# Pressure_Alarm                          -0.106099
# Inclination_Angle                       -0.103705
# Location_Fault_Code                     -0.102703
# Operating_Pressure_above_Normal         -0.124108
# Vandalism_Reports                       -0.030911
# Compression_Ratio                       -0.082738
# Multiple_Connects                       -0.084792
# Water_Exposure_units                    -0.088829
# Humidity_Factor                          0.013853
# Cathodic_Protection                      0.078179
# Pressure_Class                          -0.136602
# Latitude                                -0.006237
# Longitude                                0.010086
# Failure_NextHour                         1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# We find no correlation values that require further attention, apart from Long/Lat being low. There are also no missing values.
#
#
# Next, we want to check the proportion of machines that do fail

# %%
np.mean(df.Failure_NextHour)
#~18% failures, stratfify sampling for better accuracy
# Out:
# 0.1788908254521558

# %% [markdown]
# We find that there is roughly 18% of failures in the data. Since the number of Failures is too low, we set custom weights for training. Otherwise, a model can achieve a baseline 82% accuracy simply by predicting no failures at all.

# %% [markdown]
# ## Preprocessing
# ### Scaling
#
# The next step is for preparing the data for training. We find the range of values in the columns to vary greatly, to ensure one variable does not outweigh the other in models that use objective functions in  $L^p$ space, we scale and center all columns, to preserve variance while removing "units".
#
# To scale new data, the mean and variance of training data is used. As such, we create a custom $\texttt{scaler}$ object that scales the data and saves the required variables for use in scoring later.
#
# For an accurate look at our final model prediction accuracy, we split the data into training and test sets before we scale. The $\texttt{scaler}$ object will contain mean and variance learnt only on the training data. We also enforce a stratified split of the $y$ variable, to ensure a good estimate during testing.

# %%
X = df.drop('Failure_NextHour', 1)
y = df['Failure_NextHour']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, stratify = y)

# %% [markdown]
# As mentioned above, we will declare custom weights for training, with 4 times higher weight for Failures.

# %%
weights = np.array(y_train*4 + 1)

# %%
class scaler:
    def __init__(self, x = None):
        if type(x) == pd.core.frame.DataFrame:
            self.fit(x)
        elif x == None:
            self.x = None
            self.mean = None
            self.var = None
        else:
            raise Exception('Require pandas.DF input')


    def fit(self, x):
        self.x = x
        self.mean = x.mean()
        self.var = x.var()

    def scale(self, new_x):
        result = (new_x - self.mean) / np.sqrt(self.var)
        return (result)

# %%
s = scaler(X_train)

pickle.dump(s, open('scaler.pkl', 'wb'))
X_scale = s.scale(X_train)
X_scale.boxplot(rot=90) #Preserves corr, prevents skew for linear models, good for PCA

# %% [markdown]
# In the plot above we examine the variables post scaling. We identify some outliers in Abnormal_Flow_Rate. We would normally do further investigation into these outliers but without more information on what each column represents, we cannot confidently remove these. There are also not many outliers and will likely not skew the results too much.
#
# At this point, we are done with data exploration and cleaning.

# %% [markdown]
# ### Principal Component Analysis
#
# We lack information about the data rows, and no insight on the machine the telemetry comes from. We can fix this issue by relying on PCA to pick out relevant variables.
#
# $\textbf{NOTE}$: AutoML will try PCA in its pipeline. However, to generalise the data processing pipeline, this is left in and still done manually.

# %%
len(princomps)
# Out:
# 10

# %%
from sklearn.decomposition import PCA

pca = PCA()
X_pca = pca.fit_transform(X_scale)
pickle.dump(pca,open('pca_transform.pkl','wb'))
pcvars = pca.explained_variance_ratio_
print("Sum of first n PCs:")
print([sum(pcvars[:i+1]) for i in range(len(pcvars))])
princomps = pca.components_[:10].round(decimals = 3)
#print(princomps)
pc_df = pd.DataFrame(index = X.columns)
for i in range(len(princomps)):
    pc_df['PC {}'.format(i+1)] = princomps[i] 
print(pc_df)
# Out:
# Sum of first n PCs:
# [0.3793508065661612, 0.5050473711153893, 0.5860832754720627, 0.6407008461068049, 0.6930465143585615, 0.7417097046997754, 0.7875978547172637, 0.8286259066423872, 0.8668462083179238, 0.901365830655342, 0.9220894244812752, 0.9386322535103159, 0.9521787662778578, 0.9632346173504764, 0.9733543566209524, 0.9831718791635806, 0.9897753915350717, 0.9948210016177212, 0.9974418910848172, 0.9991168225475049, 0.9997332013726313, 0.9999971447033873, 1.0000000000000002]
#                                   PC 1   PC 2   PC 3   PC 4   PC 5   PC 6  \
# Density_Overload                 0.280  0.177  0.165 -0.034  0.173 -0.197
# Abnormal_Flow_Rate               0.040  0.076  0.231 -0.292  0.251 -0.052
# Heat_Flow                        0.307  0.034 -0.066 -0.120  0.167  0.086
# Asset_Integrity                  0.163  0.269 -0.469 -0.186 -0.169  0.115
# Temperature_Differential         0.149  0.099  0.089 -0.470  0.156  0.374
# Volumetric_Flow_Rate             0.287 -0.245 -0.105  0.141  0.065 -0.101
# Tangential_Stress                0.286 -0.258 -0.095  0.145  0.064 -0.093
# Duct_Lengths_in_Units            0.229 -0.256  0.045 -0.205  0.047  0.043
# Fault_in_last_Month             -0.096 -0.150  0.259  0.045  0.240  0.383
# Avg_hours_in_Use                 0.282 -0.224 -0.120  0.161  0.079 -0.110
# Pressure_Alarm                   0.144 -0.172  0.226 -0.200 -0.616  0.092
# Inclination_Angle                0.255 -0.237 -0.068  0.019  0.048 -0.048
# Location_Fault_Code              0.237  0.217  0.010  0.364 -0.072  0.163
# Operating_Pressure_above_Normal  0.220 -0.292 -0.090  0.053 -0.027 -0.115
# Vandalism_Reports                0.094  0.149  0.173  0.522 -0.082  0.477
# Compression_Ratio                0.245  0.317 -0.057  0.121 -0.080  0.044
# Multiple_Connects                0.283  0.125  0.196  0.009  0.145  0.105
# Water_Exposure_units             0.274  0.173  0.244 -0.113  0.179 -0.022
# Humidity_Factor                  0.166  0.388 -0.307 -0.125 -0.163 -0.120
# Cathodic_Protection             -0.000 -0.271 -0.400 -0.151 -0.019  0.557
# Pressure_Class                   0.172 -0.063  0.366 -0.120 -0.519 -0.020
# Latitude                        -0.006  0.002  0.008  0.050 -0.042 -0.035
# Longitude                       -0.001  0.001  0.001 -0.040 -0.018  0.028
#
#                                   PC 7   PC 8   PC 9  PC 10
# Density_Overload                -0.004 -0.002 -0.089  0.111
# Abnormal_Flow_Rate              -0.030  0.084  0.874 -0.011
# Heat_Flow                       -0.009 -0.016 -0.017  0.120
# Asset_Integrity                  0.000 -0.000  0.094  0.173
# Temperature_Differential        -0.009 -0.098 -0.274 -0.305
# Volumetric_Flow_Rate            -0.005  0.015  0.030  0.097
# Tangential_Stress               -0.005  0.015  0.036  0.057
# Duct_Lengths_in_Units            0.001 -0.033 -0.055 -0.290
# Fault_in_last_Month             -0.006 -0.000 -0.083  0.719
# Avg_hours_in_Use                -0.005  0.018  0.034  0.151
# Pressure_Alarm                   0.022  0.010  0.047  0.125
# Inclination_Angle               -0.004  0.008  0.036 -0.032
# Location_Fault_Code              0.004  0.032  0.079  0.007
# Operating_Pressure_above_Normal -0.005  0.006  0.043 -0.195
# Vandalism_Reports               -0.001  0.021  0.189 -0.333
# Compression_Ratio                0.006  0.012  0.026  0.080
# Multiple_Connects               -0.003 -0.021 -0.142 -0.015
# Water_Exposure_units            -0.006 -0.024 -0.152  0.000
# Humidity_Factor                  0.004  0.006  0.030  0.163
# Cathodic_Protection             -0.008 -0.015  0.152  0.030
# Pressure_Class                   0.023  0.006  0.036  0.111
# Latitude                        -0.702 -0.704  0.068  0.028
# Longitude                       -0.710  0.695 -0.098 -0.024

# %% [markdown]
# We check the explained variance of the first $n \in (1,...,10)$ principal components. The first 10 PCs contain 90% of variance in the data, small increases after. Will use only 10 PCs for subsequent modelling.

# %%
X_pca = X_pca[:,:10]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('1st Principal Component', fontsize = 15)
ax.set_ylabel('2nd Principal Component', fontsize = 15)
ax.set_title('PCA Plot (2 PC)', fontsize = 20)

cols = ['r', 'b']
for f in [0,1]:
    idx = y_train == f
    ax.scatter(X_pca[idx, 0], X_pca[idx, 1], color = cols[f], s = 50)
    
ax.legend(['Ok','Failure'])
ax.grid()

# %% [markdown]
# If we examine the plot above. We see the first two PCs (total 50% explained variance) can already segment the Failures into a noticeable area of its own. This gives us confidence in using the PCs for modelling instead of the variables directly.

# %% [markdown]
# ### AutoML Modelling
#
# In this notebook, we will use AutoML for modelling for speed and scale. Begin with importing relevant modules and loading pre-configured workspace.
#
# This is trained locally on a DSVM.

# %%
import azureml.core
azureml.core.VERSION

import logging
import os
import random

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.train.automl.run import AutoMLRun

ws = Workspace.from_config()

exp_name = 'jmc-maintenance'
experiment=Experiment(ws, exp_name)
exp_list = ws.experiments
# Out:
# Found the config file in: C:\Users\zhpek\Desktop\C4TS-Challenge4\aml_config\config.json

# %% [markdown]
# We set up the training config, in this case, we use a simple 5-fold cross validation. We use custom weights as defined in the step above for training. We are concerned with false positives (wasting time maintaining healthy machines) as well as needing to ensure machines don't break down. This means recall and precision are extremely important, so we want to use weighted f1 sore as the primary metric. However, AutoML currently does not support f1 score, so we instead choose to optimise for average precision which also takes both precision and recall into account at this stage.

# %%
config = AutoMLConfig(task = 'classification',
                             debug_log = 'automl_errors.log',
                             primary_metric = 'average_precision_score_weighted',
                             iterations = 3,
                             n_cross_validations = 5,
                             verbosity = logging.INFO,
                             max_concurrent_iterations = 10,
                             sample_weight = weights,
                             X = X_pca, 
                             y = np.array(y_train))

# %% [markdown]
# The next cell creates a new run if this is the first run, but if an existing run has been conducted, then it continues the training. This facilitates retraining in the future, and does not "waste" the previous runs completed. At the end of training, we upload files required for preprocessing into the run itself.

# %%
if exp_name in exp_list:
    #AutoMLRun(experiment = experiment, run_id = run.id)
    run = AutoMLRun(experiment = experiment, run_id = list(experiment.get_runs())[0].id)
    run = run.continue_experiment(X = X_pca,
                                  y = np.array(y_train),
                                  show_output = True,
                                  sample_weight = weights,
                                  iterations = 30
                             )
else:
    run = experiment.submit(config, show_output=True) #

run.upload_file('pca_transform.pkl','pca_transform.pkl')
run.upload_file('scaler.pkl','scaler.pkl')
# Out:
# Parent Run ID: AutoML_682e01c5-d55f-4d45-8158-5db7c7a927c4
# *******************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# *******************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
#          0   RobustScaler RandomForest                      0:00:48       0.6677    0.6677
#          1   MaxAbsScaler LightGBM                          0:00:05       0.6866    0.6866
#          2    Ensemble                                      0:00:08       0.6873    0.6873

# %% [markdown]
# From the runs completed, get the best model outputs and register them to Machine Learning Workspace.

# %%
best_iter, model = run.get_output()

# %% [markdown]
# We quickly check the model provided on our test data to estimate accuracy we can expect from our final model. Note that this is not necessarily the model we will use, since we will select based on a different metric

# %%
prediction = model.predict(pca.transform(X_test)[:,:10])
print('Accuracy: ' + str(np.mean(prediction == y_test)))
print('Recall: ' + str(np.mean(prediction[y_test==1] == 1)))
print('Precision: ' + str(np.mean(y_test[prediction==1] == 1)))
print('False Negatives: ' + str(np.mean(y_test[prediction==0] == 1))) #Missed this number of failures
print('False Positives: ' + str(np.mean(y_test[prediction==1] == 0))) #Checked unneccesarily
# Out:
# Accuracy: 0.7451428571428571
# Recall: 0.07827476038338659
# Precision: 0.1346153846153846
# False Negatives: 0.1839923469387755
# False Positives: 0.8653846153846154
