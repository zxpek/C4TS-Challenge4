# %%
import pandas as pd
import numpy as np
import pickle

df = pd.read_csv('AssetData_Historical.csv')#.drop(['Machine_ID', 'Latitude', 'Longitude'], 1) #LongLat not unique with District
df_test = pd.read_csv('AssetData_New.csv').drop(['Machine_ID', 'Latitude', 'Longitude'], 1) #LongLat not unique with District

# %%
df.head()
# Out:
#    Machine_ID  Density_Overload  Abnormal_Flow_Rate  Heat_Flow  \
# 0      111436              7877                   2       7879
# 1      185081              7877                   2       7879
# 2      111413              7099                   1       7100
# 3      185070              7099                   1       7100
# 4      111385              7797                   3       7800
#
#    Asset_Integrity  Temperature_Differential  Volumetric_Flow_Rate  \
# 0           783360                      1062                  1576
# 1           783360                      1062                  1576
# 2           783360                       844                  1682
# 3           783360                       844                  1682
# 4           783360                      1029                  1604
#
#    Tangential_Stress  Duct_Lengths_in_Units  Fault_in_last_Month  \
# 0               1716                   1978                    0
# 1               1716                   1978                    0
# 2               1698                   1715                    0
# 3               1698                   1715                    0
# 4               1641                   1880                    0
#
#          ...         Compression_Ratio  Multiple_Connects  \
# 0        ...                         3                785
# 1        ...                         3                785
# 2        ...                         3                722
# 3        ...                         3                722
# 4        ...                         3                836
#
#    Water_Exposure_units  Humidity_Factor  Cathodic_Protection  Pressure_Class  \
# 0                  3139              128                    1               1
# 1                  3139              128                    1               1
# 2                  2874              128                    1               1
# 3                  2874              128                    1               1
# 4                  4831              128                    1               1
#
#             District  Latitude  Longitude  Failure_NextHour
# 0             Rochor      1,31     103,87                 0
# 1       Geylang West      1,32     103,89                 0
# 2        Hume Estate      1,35     103,82                 0
# 3       Little India      1,31     103,85                 0
# 4  Jurong?esidential      1,35     103,82                 1
#
# [5 rows x 26 columns]

# %%
def cleanLongLat(l):
    split = l.str.split(',', expand=True)
    split = (split[0]+'.'+[i if len(i)>1 else i+'0' for i in split[1]]).astype(float)
    return(split)

df['Latitude'] = cleanLongLat(df['Latitude'])
df['Longitude'] = cleanLongLat(df['Longitude'])

# %%
df.boxplot(column='Latitude')

# %%
df.boxplot(column='Longitude')

# %%
df.isnull().sum()
# Out:
# Machine_ID                         0
# Density_Overload                   0
# Abnormal_Flow_Rate                 0
# Heat_Flow                          0
# Asset_Integrity                    0
# Temperature_Differential           0
# Volumetric_Flow_Rate               0
# Tangential_Stress                  0
# Duct_Lengths_in_Units              0
# Fault_in_last_Month                0
# Avg_hours_in_Use                   0
# Pressure_Alarm                     0
# Inclination_Angle                  0
# Location_Fault_Code                0
# Operating_Pressure_above_Normal    0
# Vandalism_Reports                  0
# Compression_Ratio                  0
# Multiple_Connects                  0
# Water_Exposure_units               0
# Humidity_Factor                    0
# Cathodic_Protection                0
# Pressure_Class                     0
# District                           0
# Latitude                           0
# Longitude                          0
# Failure_NextHour                   0
# dtype: int64

# %%
df.corr()
# Out:
#                                  Machine_ID  Density_Overload  \
# Machine_ID                         1.000000          0.096878
# Density_Overload                   0.096878          1.000000
# Abnormal_Flow_Rate                 0.016056          0.213953
# Heat_Flow                          0.068645          0.816754
# Asset_Integrity                   -0.036125          0.351662
# Temperature_Differential           0.058190          0.377343
# Volumetric_Flow_Rate               0.125887          0.570871
# Tangential_Stress                  0.127674          0.556368
# Duct_Lengths_in_Units              0.166875          0.430534
# Fault_in_last_Month               -0.014250         -0.220760
# Avg_hours_in_Use                   0.116137          0.577219
# Pressure_Alarm                     0.097564          0.209107
# Inclination_Angle                  0.121840          0.474311
# Location_Fault_Code                0.053597          0.604754
# Operating_Pressure_above_Normal    0.120138          0.345853
# Vandalism_Reports                  0.025852          0.193853
# Compression_Ratio                  0.052349          0.679247
# Multiple_Connects                  0.096683          0.820239
# Water_Exposure_units               0.097001          0.908305
# Humidity_Factor                   -0.013781          0.506550
# Cathodic_Protection               -0.053934         -0.351434
# Pressure_Class                     0.124425          0.408092
# Latitude                          -0.006023         -0.010312
# Longitude                          0.001576         -0.004230
# Failure_NextHour                   0.411650         -0.087024
#
#                                  Abnormal_Flow_Rate  Heat_Flow  \
# Machine_ID                                 0.016056   0.068645
# Density_Overload                           0.213953   0.816754
# Abnormal_Flow_Rate                         1.000000   0.172850
# Heat_Flow                                  0.172850   1.000000
# Asset_Integrity                           -0.004151   0.530835
# Temperature_Differential                   0.124482   0.465880
# Volumetric_Flow_Rate                       0.003325   0.740692
# Tangential_Stress                          0.008282   0.724796
# Duct_Lengths_in_Units                      0.084355   0.587358
# Fault_in_last_Month                        0.011510  -0.201193
# Avg_hours_in_Use                          -0.000094   0.744314
# Pressure_Alarm                             0.024607   0.278216
# Inclination_Angle                          0.039676   0.632748
# Location_Fault_Code                        0.050702   0.570373
# Operating_Pressure_above_Normal           -0.002889   0.481982
# Vandalism_Reports                          0.043134   0.177770
# Compression_Ratio                          0.087553   0.632241
# Multiple_Connects                          0.144965   0.801082
# Water_Exposure_units                       0.218419   0.788693
# Humidity_Factor                            0.036166   0.483371
# Cathodic_Protection                       -0.096641   0.132709
# Pressure_Class                             0.106887   0.336258
# Latitude                                  -0.004386  -0.014915
# Longitude                                  0.010395  -0.002667
# Failure_NextHour                          -0.021901  -0.053134
#
#                                  Asset_Integrity  Temperature_Differential  \
# Machine_ID                             -0.036125                  0.058190
# Density_Overload                        0.351662                  0.377343
# Abnormal_Flow_Rate                     -0.004151                  0.124482
# Heat_Flow                               0.530835                  0.465880
# Asset_Integrity                         1.000000                  0.258145
# Temperature_Differential                0.258145                  1.000000
# Volumetric_Flow_Rate                    0.258186                  0.183473
# Tangential_Stress                       0.237170                  0.186437
# Duct_Lengths_in_Units                   0.119656                  0.382701
# Fault_in_last_Month                    -0.372188                 -0.074888
# Avg_hours_in_Use                        0.276150                  0.158436
# Pressure_Alarm                          0.065104                  0.161712
# Inclination_Angle                       0.223164                  0.240396
# Location_Fault_Code                     0.427324                  0.243451
# Operating_Pressure_above_Normal         0.142548                  0.170019
# Vandalism_Reports                       0.056072                  0.085021
# Compression_Ratio                       0.622167                  0.328921
# Multiple_Connects                       0.298326                  0.474112
# Water_Exposure_units                    0.292916                  0.517217
# Humidity_Factor                         0.911570                  0.234152
# Cathodic_Protection                     0.248745                  0.066515
# Pressure_Class                          0.031216                  0.210291
# Latitude                               -0.011228                 -0.009762
# Longitude                               0.002324                  0.000105
# Failure_NextHour                        0.046219                 -0.060799
#
#                                  Volumetric_Flow_Rate  Tangential_Stress  \
# Machine_ID                                   0.125887           0.127674
# Density_Overload                             0.570871           0.556368
# Abnormal_Flow_Rate                           0.003325           0.008282
# Heat_Flow                                    0.740692           0.724796
# Asset_Integrity                              0.258186           0.237170
# Temperature_Differential                     0.183473           0.186437
# Volumetric_Flow_Rate                         1.000000           0.990529
# Tangential_Stress                            0.990529           1.000000
# Duct_Lengths_in_Units                        0.657269           0.681816
# Fault_in_last_Month                         -0.165331          -0.162114
# Avg_hours_in_Use                             0.985292           0.972280
# Pressure_Alarm                               0.356466           0.358604
# Inclination_Angle                            0.794028           0.796678
# Location_Fault_Code                          0.481414           0.471725
# Operating_Pressure_above_Normal              0.744896           0.776051
# Vandalism_Reports                            0.107318           0.122956
# Compression_Ratio                            0.411663           0.396725
# Multiple_Connects                            0.567000           0.560576
# Water_Exposure_units                         0.487839           0.480895
# Humidity_Factor                              0.187735           0.166028
# Cathodic_Protection                          0.176347           0.177116
# Pressure_Class                               0.361949           0.365949
# Latitude                                    -0.012698          -0.013039
# Longitude                                   -0.005900          -0.005754
# Failure_NextHour                            -0.099991          -0.105457
#
#                                  Duct_Lengths_in_Units  Fault_in_last_Month  \
# Machine_ID                                    0.166875            -0.014250
# Density_Overload                              0.430534            -0.220760
# Abnormal_Flow_Rate                            0.084355             0.011510
# Heat_Flow                                     0.587358            -0.201193
# Asset_Integrity                               0.119656            -0.372188
# Temperature_Differential                      0.382701            -0.074888
# Volumetric_Flow_Rate                          0.657269            -0.165331
# Tangential_Stress                             0.681816            -0.162114
# Duct_Lengths_in_Units                         1.000000            -0.136521
# Fault_in_last_Month                          -0.136521             1.000000
# Avg_hours_in_Use                              0.590984            -0.161808
# Pressure_Alarm                                0.401551            -0.037736
# Inclination_Angle                             0.643713            -0.157304
# Location_Fault_Code                           0.218514            -0.212958
# Operating_Pressure_above_Normal               0.669222            -0.175663
# Vandalism_Reports                             0.063613            -0.038184
# Compression_Ratio                             0.221804            -0.301645
# Multiple_Connects                             0.490976            -0.151786
# Water_Exposure_units                          0.485157            -0.161859
# Humidity_Factor                               0.043847            -0.417224
# Cathodic_Protection                           0.183283             0.091157
# Pressure_Class                                0.377411            -0.057409
# Latitude                                     -0.017280            -0.000137
# Longitude                                    -0.004431             0.002422
# Failure_NextHour                             -0.181797             0.021366
#
#                                        ...         Vandalism_Reports  \
# Machine_ID                             ...                  0.025852
# Density_Overload                       ...                  0.193853
# Abnormal_Flow_Rate                     ...                  0.043134
# Heat_Flow                              ...                  0.177770
# Asset_Integrity                        ...                  0.056072
# Temperature_Differential               ...                  0.085021
# Volumetric_Flow_Rate                   ...                  0.107318
# Tangential_Stress                      ...                  0.122956
# Duct_Lengths_in_Units                  ...                  0.063613
# Fault_in_last_Month                    ...                 -0.038184
# Avg_hours_in_Use                       ...                  0.106568
# Pressure_Alarm                         ...                  0.070162
# Inclination_Angle                      ...                  0.097147
# Location_Fault_Code                    ...                  0.543504
# Operating_Pressure_above_Normal        ...                  0.049842
# Vandalism_Reports                      ...                  1.000000
# Compression_Ratio                      ...                  0.364533
# Multiple_Connects                      ...                  0.358372
# Water_Exposure_units                   ...                  0.249677
# Humidity_Factor                        ...                  0.080323
# Cathodic_Protection                    ...                 -0.055145
# Pressure_Class                         ...                  0.168251
# Latitude                               ...                  0.003696
# Longitude                              ...                 -0.002693
# Failure_NextHour                       ...                 -0.030911
#
#                                  Compression_Ratio  Multiple_Connects  \
# Machine_ID                                0.052349           0.096683
# Density_Overload                          0.679247           0.820239
# Abnormal_Flow_Rate                        0.087553           0.144965
# Heat_Flow                                 0.632241           0.801082
# Asset_Integrity                           0.622167           0.298326
# Temperature_Differential                  0.328921           0.474112
# Volumetric_Flow_Rate                      0.411663           0.567000
# Tangential_Stress                         0.396725           0.560576
# Duct_Lengths_in_Units                     0.221804           0.490976
# Fault_in_last_Month                      -0.301645          -0.151786
# Avg_hours_in_Use                          0.417957           0.563756
# Pressure_Alarm                            0.156199           0.286395
# Inclination_Angle                         0.334078           0.506151
# Location_Fault_Code                       0.793386           0.624410
# Operating_Pressure_above_Normal           0.243430           0.352468
# Vandalism_Reports                         0.364533           0.358372
# Compression_Ratio                         1.000000           0.663890
# Multiple_Connects                         0.663890           1.000000
# Water_Exposure_units                      0.658881           0.905253
# Humidity_Factor                           0.717192           0.369289
# Cathodic_Protection                      -0.198991          -0.155732
# Pressure_Class                            0.304457           0.424383
# Latitude                                 -0.009476          -0.012404
# Longitude                                -0.006248          -0.003114
# Failure_NextHour                         -0.082738          -0.084792
#
#                                  Water_Exposure_units  Humidity_Factor  \
# Machine_ID                                   0.097001        -0.013781
# Density_Overload                             0.908305         0.506550
# Abnormal_Flow_Rate                           0.218419         0.036166
# Heat_Flow                                    0.788693         0.483371
# Asset_Integrity                              0.292916         0.911570
# Temperature_Differential                     0.517217         0.234152
# Volumetric_Flow_Rate                         0.487839         0.187735
# Tangential_Stress                            0.480895         0.166028
# Duct_Lengths_in_Units                        0.485157         0.043847
# Fault_in_last_Month                         -0.161859        -0.417224
# Avg_hours_in_Use                             0.478507         0.208780
# Pressure_Alarm                               0.257043         0.033792
# Inclination_Angle                            0.471435         0.151664
# Location_Fault_Code                          0.577725         0.493440
# Operating_Pressure_above_Normal              0.320423         0.073082
# Vandalism_Reports                            0.249677         0.080323
# Compression_Ratio                            0.658881         0.717192
# Multiple_Connects                            0.905253         0.369289
# Water_Exposure_units                         1.000000         0.419353
# Humidity_Factor                              0.419353         1.000000
# Cathodic_Protection                         -0.287003        -0.171319
# Pressure_Class                               0.435236         0.100191
# Latitude                                    -0.010432        -0.006013
# Longitude                                   -0.001526        -0.000728
# Failure_NextHour                            -0.088829         0.013853
#
#                                  Cathodic_Protection  Pressure_Class  \
# Machine_ID                                 -0.053934        0.124425
# Density_Overload                           -0.351434        0.408092
# Abnormal_Flow_Rate                         -0.096641        0.106887
# Heat_Flow                                   0.132709        0.336258
# Asset_Integrity                             0.248745        0.031216
# Temperature_Differential                    0.066515        0.210291
# Volumetric_Flow_Rate                        0.176347        0.361949
# Tangential_Stress                           0.177116        0.365949
# Duct_Lengths_in_Units                       0.183283        0.377411
# Fault_in_last_Month                         0.091157       -0.057409
# Avg_hours_in_Use                            0.169817        0.338580
# Pressure_Alarm                              0.076367        0.711562
# Inclination_Angle                           0.177373        0.336392
# Location_Fault_Code                        -0.138646        0.309484
# Operating_Pressure_above_Normal             0.169438        0.311583
# Vandalism_Reports                          -0.055145        0.168251
# Compression_Ratio                          -0.198991        0.304457
# Multiple_Connects                          -0.155732        0.424383
# Water_Exposure_units                       -0.287003        0.435236
# Humidity_Factor                            -0.171319        0.100191
# Cathodic_Protection                         1.000000       -0.161861
# Pressure_Class                             -0.161861        1.000000
# Latitude                                   -0.012933       -0.001657
# Longitude                                   0.007185       -0.001899
# Failure_NextHour                            0.078179       -0.136602
#
#                                  Latitude  Longitude  Failure_NextHour
# Machine_ID                      -0.006023   0.001576          0.411650
# Density_Overload                -0.010312  -0.004230         -0.087024
# Abnormal_Flow_Rate              -0.004386   0.010395         -0.021901
# Heat_Flow                       -0.014915  -0.002667         -0.053134
# Asset_Integrity                 -0.011228   0.002324          0.046219
# Temperature_Differential        -0.009762   0.000105         -0.060799
# Volumetric_Flow_Rate            -0.012698  -0.005900         -0.099991
# Tangential_Stress               -0.013039  -0.005754         -0.105457
# Duct_Lengths_in_Units           -0.017280  -0.004431         -0.181797
# Fault_in_last_Month             -0.000137   0.002422          0.021366
# Avg_hours_in_Use                -0.012246  -0.006712         -0.084762
# Pressure_Alarm                  -0.005250   0.006143         -0.106099
# Inclination_Angle               -0.015071  -0.003345         -0.103705
# Location_Fault_Code             -0.010044  -0.003759         -0.102703
# Operating_Pressure_above_Normal -0.010180  -0.002810         -0.124108
# Vandalism_Reports                0.003696  -0.002693         -0.030911
# Compression_Ratio               -0.009476  -0.006248         -0.082738
# Multiple_Connects               -0.012404  -0.003114         -0.084792
# Water_Exposure_units            -0.010432  -0.001526         -0.088829
# Humidity_Factor                 -0.006013  -0.000728          0.013853
# Cathodic_Protection             -0.012933   0.007185          0.078179
# Pressure_Class                  -0.001657  -0.001899         -0.136602
# Latitude                         1.000000   0.054408         -0.006237
# Longitude                        0.054408   1.000000          0.010086
# Failure_NextHour                -0.006237   0.010086          1.000000
#
# [25 rows x 25 columns]

# %%
df.drop(['Machine_ID', 'District'], axis=1, inplace=True)

# %%
X = df.drop('Failure_NextHour', 1)
y = df['Failure_NextHour']

# %%
type(X) == pd.core.frame.DataFrame
# Out:
# True

# %%
class scaler:
    def __init__(self, x = None):
        if type(x) == pd.core.frame.DataFrame:
            self.fit(x)
        elif x == None:
            self.x = None
            self.mean = None
            self.var = None
        else:
            raise Exception('Require pandas.DF input')
            
        
    def fit(self, x):
        self.x = x
        self.mean = x.mean()
        self.var = x.var()
        
    def scale(self):
        result = (self.x - self.x.mean()) / np.sqrt(self.x.var())
        return (result)

# %%
s = scaler(X)

pickle.dump(s, open('scaler.pkl', 'wb'))
X_scale = s.scale()
X_scale.boxplot(rot=90) #Preserves corr, prevents skew for linear models, good for PCA

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size = 0.1, stratify = y)

# %%
np.mean(y_train)
#~18% failures, stratfify sampling for better accuracy
# Out:
# 0.1788945680815264

# %%
weights = np.array(y_train*4 + 1)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 'mle', svd_solver ='full')
X_pca = pca.fit_transform(X_train)
pickle.dump(pca,open('pca_transform.pkl','wb'))

# %%
import azureml.core
azureml.core.VERSION

import logging
import os
import random

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.train.automl.run import AutoMLRun

ws = Workspace.from_config()

exp_name = 'c4ts-challenge4'
experiment=Experiment(ws, exp_name)
# Out:
# Found the config file in: C:\Users\zhpek\Desktop\C4I\Challenge 4\aml_config\config.json

# %%
config = AutoMLConfig(task = 'classification',
                             debug_log = 'automl_errors.log',
                             primary_metric = 'AUC_weighted',
                             iterations = 3,
                             n_cross_validations = 5,
                             verbosity = logging.INFO,
                             max_concurrent_iterations = 6,#NV6 DSVM, use 6 cores
                             sample_weight = weights,
                             X = X_pca, 
                             y = np.array(y_train))

# %%
run = experiment.submit(config, show_output=True)
run.upload_file('pca_transform.pkl','pca_transform.pkl')
run.upload_file('scaler.pkl','scaler.pkl')
# Out:
# Parent Run ID: AutoML_de68d57f-dbc9-445a-bd87-229040fbabe0
# *******************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# *******************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
#          0   MinMaxScaler LightGBM                          0:00:32       0.7625    0.7625
#          1   MaxAbsScaler LightGBM                          0:00:21       0.7890    0.7890
#          2    Ensemble                                      0:00:40       0.7890    0.7890

# %%
best_iter, model = run.get_output()

# %%
print('Accuracy: ' + str(np.mean(model.predict(pca.transform(X_test)) == y_test)))
prediction = model.predict(pca.transform(X_test))
print('True Positives: ' + str(np.mean(prediction[y_test==1] == y_test[y_test == 1])))
# Out:
# Accuracy: 0.6468571428571429
# True Positives: 0.8626198083067093

# %%
model.predict_proba(pca.transform(X_test))>0.5
# Out:
# array([[ True, False],
#        [False,  True],
#        [ True, False],
#        ...,
#        [ True, False],
#        [False,  True],
#        [False,  True]])

# %%
model.predict(pca.transform(X_test))
# Out:
# array([0, 1, 0, ..., 0, 1, 1], dtype=int64)

# %%
m = run.register_model(description='Challenge 4 - Scaled, 10 principal components')
# Out:
# Registering model AutoMLde68d57fdbest

# %%
#last = [i for i in experiment.get_runs()][-1]
#lastrun = [i for i in last.get_children()][-1]
#lastrun.get_file_names()
#lastrun.download_file('outputs/model.pkl')
#m = pickle.load(open("model.pkl","rb"))
#m.predict(pca.transform(X_test))
# Out:
# azureml.train.automl.run.AutoMLRun
