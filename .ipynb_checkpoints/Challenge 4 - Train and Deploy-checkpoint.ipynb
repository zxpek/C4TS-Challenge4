# %%
import pandas as pd
import numpy as np
import pickle

df = pd.read_csv('C:\\Users\zhpek\OneDrive - Microsoft\Projects\C4I\Challenge 4\AssetData_Historical.csv')#.drop(['Machine_ID', 'Latitude', 'Longitude'], 1) #LongLat not unique with District
df_test = pd.read_csv('C:\\Users\zhpek\OneDrive - Microsoft\Projects\C4I\Challenge 4\AssetData_New.csv').drop(['Machine_ID', 'Latitude', 'Longitude'], 1) #LongLat not unique with District

# %%
df.head()
# Out:
#    Machine_ID  Density_Overload  Abnormal_Flow_Rate  Heat_Flow  \
# 0      111436              7877                   2       7879
# 1      185081              7877                   2       7879
# 2      111413              7099                   1       7100
# 3      185070              7099                   1       7100
# 4      111385              7797                   3       7800
#
#    Asset_Integrity  Temperature_Differential  Volumetric_Flow_Rate  \
# 0           783360                      1062                  1576
# 1           783360                      1062                  1576
# 2           783360                       844                  1682
# 3           783360                       844                  1682
# 4           783360                      1029                  1604
#
#    Tangential_Stress  Duct_Lengths_in_Units  Fault_in_last_Month  \
# 0               1716                   1978                    0
# ...

# %%
def cleanLongLat(l):
    split = l.str.split(',', expand=True)
    split = (split[0]+'.'+[i if len(i)>1 else i+'0' for i in split[1]]).astype(float)
    return(split)

df['Latitude'] = cleanLongLat(df['Latitude'])
df['Longitude'] = cleanLongLat(df['Longitude'])

# %%
df.boxplot(column='Latitude')

# %%
df.boxplot(column='Longitude')

# %%
df.isnull().sum()
# Out:
# Machine_ID                         0
# Density_Overload                   0
# Abnormal_Flow_Rate                 0
# Heat_Flow                          0
# Asset_Integrity                    0
# Temperature_Differential           0
# Volumetric_Flow_Rate               0
# Tangential_Stress                  0
# Duct_Lengths_in_Units              0
# Fault_in_last_Month                0
# Avg_hours_in_Use                   0
# Pressure_Alarm                     0
# Inclination_Angle                  0
# Location_Fault_Code                0
# Operating_Pressure_above_Normal    0
# Vandalism_Reports                  0
# Compression_Ratio                  0
# Multiple_Connects                  0
# Water_Exposure_units               0
# Humidity_Factor                    0
# Cathodic_Protection                0
# Pressure_Class                     0
# District                           0
# Latitude                           0
# Longitude                          0
# ...

# %%
df.corr()
# Out:
#                                  Machine_ID  Density_Overload  \
# Machine_ID                         1.000000          0.096878
# Density_Overload                   0.096878          1.000000
# Abnormal_Flow_Rate                 0.016056          0.213953
# Heat_Flow                          0.068645          0.816754
# Asset_Integrity                   -0.036125          0.351662
# Temperature_Differential           0.058190          0.377343
# Volumetric_Flow_Rate               0.125887          0.570871
# Tangential_Stress                  0.127674          0.556368
# Duct_Lengths_in_Units              0.166875          0.430534
# Fault_in_last_Month               -0.014250         -0.220760
# Avg_hours_in_Use                   0.116137          0.577219
# Pressure_Alarm                     0.097564          0.209107
# Inclination_Angle                  0.121840          0.474311
# Location_Fault_Code                0.053597          0.604754
# ...

# %%
df.drop(['Machine_ID', 'District'], axis=1, inplace=True)

# %%
df_scale = (df - df.mean()) / np.sqrt(df.var())
df_scale.boxplot(rot=90) #Preserves corr, prevents skew for linear models, good for PCA

# %%
X_train = df_scale.drop('Failure_NextHour', 1)
y_train = df_scale['Failure_NextHour']

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 'mle', svd_solver ='full')
X_pca = pca.fit_transform(X_train)
#pickle.dump(X_pca, open( "X_pca.p", "wb" ))
#X_pca = pickle.load(open("X_pca.p", "rb"))

# %%
import azureml.core
azureml.core.VERSION

import logging
import os
import random

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.train.automl.run import AutoMLRun

# %%
ws = Workspace.from_config()

exp_name = 'c4ts-challenge4'

experiment=Experiment(ws, exp_name)

output = {}
output['SDK version'] = azureml.core.VERSION
output['Subscription ID'] = ws.subscription_id
output['Workspace Name'] = ws.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location
output['Experiment Name'] = experiment.name
pd.set_option('display.max_colwidth', -1)
pd.DataFrame(data = output, index = ['']).T
# Out:
# Found the config file in: C:\Users\zhpek\OneDrive - Microsoft\Projects\C4I\Challenge 4\aml_config\config.json
#
# SDK version      1.0.2
# Subscription ID  50fb2758-5add-47ee-b8f2-9c9ae596fed5
# Workspace Name   pekamlworkspace
# Resource Group   pekamlrg
# Location         eastus2
# Experiment Name  c4ts-challenge4

# %%
automl_config = AutoMLConfig(task = 'classification',
                             debug_log = 'automl_errors.log',
                             primary_metric = 'AUC_weighted',
                             iterations = 5,
                             n_cross_validations = 5,
                             verbosity = logging.INFO,
                             X = X_pca, 
                             y = np.array(y_train))

# %%
run = experiment.submit(automl_config, show_output=True)
# Out:
# Parent Run ID: AutoML_e0ee5031-a710-4ffc-b990-56002eb89209
# *******************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# *******************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
#          0
