# %%
import azureml.core
azureml.core.VERSION
# Out:
# '0.1.59'

# %%
import logging
import os
import random

from matplotlib import pyplot as plt
from matplotlib.pyplot import imshow
import numpy as np
import pandas as pd
from sklearn import datasets

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.train.automl.run import AutoMLRun
# Out:
# C:\Users\zhpek\AppData\Local\Continuum\anaconda3\envs\amlenv\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
ws = Workspace.from_config()

# choose a name for experiment
experiment_name = 'aks-compute-trial'
# project folder
project_folder = 'aks-compute-trial'

experiment=Experiment(ws, experiment_name)

output = {}
output['SDK version'] = azureml.core.VERSION
output['Subscription ID'] = ws.subscription_id
output['Workspace Name'] = ws.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location
output['Project Directory'] = project_folder
output['Experiment Name'] = experiment.name
pd.set_option('display.max_colwidth', -1)
pd.DataFrame(data = output, index = ['']).T
# Out:
# Found the config file in: C:\Users\zhpek\OneDrive - Microsoft\Demos\AzureML\aml_config\config.json
#
# SDK version        0.1.59
# Subscription ID    50fb2758-5add-47ee-b8f2-9c9ae596fed5
# Workspace Name     pekamlworkspace
# Resource Group     pekamlrg
# Location           eastus2
# Project Directory  aks-compute-trial
# Experiment Name    aks-compute-trial

# %%
from azureml.core.compute import ComputeTarget, BatchAiCompute
from azureml.core.compute_target import ComputeTargetException

# choose a name for your cluster
batchai_cluster_name = "pekbatchai"

compute_target = ComputeTarget(workspace = ws, name = batchai_cluster_name)

print(type(compute_target) is BatchAiCompute)
# Out:
# True

# %%
import os
import urllib.request

os.makedirs('./data', exist_ok = True)

urllib.request.urlretrieve('http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz', filename='./data/train-images.gz')
urllib.request.urlretrieve('http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz', filename='./data/train-labels.gz')
urllib.request.urlretrieve('http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz', filename='./data/test-images.gz')
urllib.request.urlretrieve('http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz', filename='./data/test-labels.gz')
# Out:
# ('./data/test-labels.gz', <http.client.HTTPMessage at 0x1b7b6c08978>)

# %%
# make sure utils.py is in the same directory as this code
from utils import load_data

# note we also shrink the intensity values (X) from 0-255 to 0-1. This helps the model converge faster.
X_train = load_data('./data/train-images.gz', False) / 255.0
y_train = load_data('./data/train-labels.gz', True).reshape(-1)

X_test = load_data('./data/test-images.gz', False) / 255.0
y_test = load_data('./data/test-labels.gz', True).reshape(-1)

# now let's show some randomly chosen images from the traininng set.
count = 0
sample_size = 30
plt.figure(figsize = (16, 6))
for i in np.random.permutation(X_train.shape[0])[:sample_size]:
    count = count + 1
    plt.subplot(1, sample_size, count)
    plt.axhline('')
    plt.axvline('')
    plt.text(x=10, y=-10, s=y_train[i], fontsize=18)
    plt.imshow(X_train[i].reshape(28, 28), cmap=plt.cm.Greys)
plt.show()

# %%
from azureml.core.datastore import Datastore
ds = Datastore.register_azure_blob_container(workspace=ws, 
                                             datastore_name='pekdatastore', 
                                             container_name='pekdefaultblob',
                                             account_name='pekdefaultstore', 
                                             account_key='SlwRHDwqx5iKKol69h6kpiFxkNEwzH3GKjJ6K/SR3CyyzY0kQb3Cjv0lpd/pRi4ojjia+GNq+YwI8EqreLKUPQ==',
                                             create_if_not_exists=False)

ws.set_default_datastore('pekdatastore')

# %%
ds = ws.get_default_datastore()
print(ds.datastore_type, ds.account_name, ds.container_name)

ds.upload(src_dir='./data', target_path='mnist', overwrite=True, show_progress=True)
# Out:
# AzureBlob pekdefaultstore pekdefaultblob
# $AZUREML_DATAREFERENCE_b06dd91a30344513b00d2e25e0067c98

# %%
# %%time
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# Wall time: 1min 20s

# %%
y_hat = clf.predict(X_test)
print(np.average(y_hat == y_test))
# Out:
# 0.9201

# %%
import os
script_folder = './batchai-mnist'
os.makedirs(script_folder, exist_ok=True)

# %%
# %%writefile $script_folder/train.py

import argparse
import os
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.externals import joblib

from azureml.core import Run
from utils import load_data

# let user feed in 2 parameters, the location of the data files (from datastore), and the regularization rate of the logistic regression model
parser = argparse.ArgumentParser()
parser.add_argument('--data-folder', type=str, dest='data_folder', help='data folder mounting point')
parser.add_argument('--regularization', type=float, dest='reg', default=0.01, help='regularization rate')
args = parser.parse_args()

data_folder = os.path.join(args.data_folder, 'mnist')
print('Data folder:', data_folder)

# load train and test set into numpy arrays
# note we scale the pixel intensity values to 0-1 (by dividing it with 255.0) so the model can converge faster.
X_train = load_data(os.path.join(data_folder, 'train-images.gz'), False) / 255.0
X_test = load_data(os.path.join(data_folder, 'test-images.gz'), False) / 255.0
y_train = load_data(os.path.join(data_folder, 'train-labels.gz'), True).reshape(-1)
y_test = load_data(os.path.join(data_folder, 'test-labels.gz'), True).reshape(-1)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, sep = '\n')

# get hold of the current run
run = Run.get_submitted_run()

print('Train a logistic regression model with regularizaion rate of', args.reg)
clf = LogisticRegression(C=1.0/args.reg, random_state=42)
clf.fit(X_train, y_train)

print('Predict the test set')
y_hat = clf.predict(X_test)

# calculate accuracy on the prediction
acc = np.average(y_hat == y_test)
print('Accuracy is', acc)

run.log('regularization rate', np.float(args.reg))
run.log('accuracy', np.float(acc))

os.makedirs('outputs', exist_ok=True)
# note file saved in the outputs folder is automatically uploaded into experiment record
joblib.dump(value=clf, filename='outputs/sklearn_mnist_model.pkl')
# Out:
# Writing ./batchai-mnist/train.py

# %%
import shutil
shutil.copy('utils.py', script_folder)
# Out:
# './batchai-mnist\\utils.py'

# %%
from azureml.train.estimator import Estimator

script_params = {
    '--data-folder': ds.as_mount(),
    '--regularization': 0.8
}

est = Estimator(source_directory=script_folder,
                script_params=script_params,
                compute_target=compute_target,
                entry_script='train.py',
                conda_packages=['scikit-learn'])

# %%
run = experiment.submit(config=est)
run

# %%
from azureml.train.widgets import RunDetails
RunDetails(run).show()
# Out:
# _UserRun()

# %%
run.wait_for_completion(show_output=True) # specify True for a verbose log
# Out:
# RunId: aks-compute-trial_1538376894240
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# Logging into Docker registry: pekamlwoacrjcvuohfw.azurecr.io
# Login Succeeded
# Docker login(s) took 1.0383009910583496 seconds
# Building image with name pekamlwoacrjcvuohfw.azurecr.io/azureml/azureml_f317120a1fc82ac7884c9fb0444dfdec
# Sending build context to Docker daemon  99.84kB
#
# Step 1/13 : FROM mcr.microsoft.com/azureml/base:0.1.3
# 0.1.3: Pulling from azureml/base
# 3b37166ec614: Pulling fs layer
# 504facff238f: Pulling fs layer
# ebbcacd28e10: Pulling fs layer
# c7fb3351ecad: Pulling fs layer
# 2e3debadcbf7: Pulling fs layer
# 515d5d7ec0fe: Pulling fs layer
# d1a5075872b0: Pulling fs layer
# 23a043b1b768: Pulling fs layer
# c178f03f40ec: Pulling fs layer
# c7fb3351ecad: Waiting
# 2e3debadcbf7: Waiting
# 515d5d7ec0fe: Waiting
# d1a5075872b0: Waiting
# 23a043b1b768: Waiting
# c178f03f40ec: Waiting
# ebbcacd28e10: Verifying Checksum
# ebbcacd28e10: Download complete
# c7fb3351ecad: Verifying Checksum
# c7fb3351ecad: Download complete
# 2e3debadcbf7: Verifying Checksum
# 2e3debadcbf7: Download complete
# 515d5d7ec0fe: Verifying Checksum
# 515d5d7ec0fe: Download complete
# d1a5075872b0: Verifying Checksum
# d1a5075872b0: Download complete
# 504facff238f: Verifying Checksum
# 504facff238f: Download complete
# 3b37166ec614: Verifying Checksum
# 3b37166ec614: Download complete
# c178f03f40ec: Verifying Checksum
# c178f03f40ec: Download complete
# 23a043b1b768: Verifying Checksum
# 23a043b1b768: Download complete
# 3b37166ec614: Pull complete
# 504facff238f: Pull complete
# ebbcacd28e10: Pull complete
# c7fb3351ecad: Pull complete
# 2e3debadcbf7: Pull complete
# 515d5d7ec0fe: Pull complete
# d1a5075872b0: Pull complete
# 23a043b1b768: Pull complete
# c178f03f40ec: Pull complete
# Digest: sha256:28eebd19420fba44a429ec1eb98539b770f4795111ecce2cc83600b5416783ab
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:0.1.3
#  ---> cafddcd9dc72
# Step 2/13 : USER root
#  ---> Running in 7c29ebdce745
#  ---> c6c26b5ee9de
# Removing intermediate container 7c29ebdce745
# Step 3/13 : RUN mkdir -p $HOME/.cache
#  ---> Running in 19f0cb95f8b5
#  ---> 54b4485ee757
# Removing intermediate container 19f0cb95f8b5
# Step 4/13 : WORKDIR /
#  ---> bcc213e75c91
# Removing intermediate container f59fc80e1207
# Step 5/13 : COPY azureml-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> d211a1d31ffa
# Step 6/13 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.0; then conda install conda==4.4.11 -c anaconda; fi
#  ---> Running in 05e9a1f6ad04
#  ---> b4e84b7861bc
# Removing intermediate container 05e9a1f6ad04
# Step 7/13 : COPY azureml-setup/mutated_conda_dependencies.yml azureml-setup/mutated_conda_dependencies.yml
#  ---> 54ad0858172d
# Step 8/13 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_088906b35cdd6596b350e033526a1806 -f azureml-setup/mutated_conda_dependencies.yml && ldconfig
#  ---> Running in 11f4482854e6
# Solving environment: ...working... done
#
# libstdcxx-ng-8.2.0   | 2.9 MB    |            |   0%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #######7   |  77%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #########9 |  99%
# libstdcxx-ng-8.2.0   | 2.9 MB    | ########## | 100%
#
# libgcc-ng-8.2.0      | 7.6 MB    |            |   0%
# libgcc-ng-8.2.0      | 7.6 MB    | ####7      |  47%
# libgcc-ng-8.2.0      | 7.6 MB    | #######6   |  76%
# libgcc-ng-8.2.0      | 7.6 MB    | #########5 |  95%
# libgcc-ng-8.2.0      | 7.6 MB    | ########## | 100%
#
# numpy-base-1.15.2    | 4.2 MB    |            |   0%
# numpy-base-1.15.2    | 4.2 MB    | #######6   |  76%
# numpy-base-1.15.2    | 4.2 MB    | ########6  |  86%
# numpy-base-1.15.2    | 4.2 MB    | #########4 |  94%
# numpy-base-1.15.2    | 4.2 MB    | ########## | 100%
#
# setuptools-40.2.0    | 556 KB    |            |   0%
# setuptools-40.2.0    | 556 KB    | ########3  |  84%
# setuptools-40.2.0    | 556 KB    | ########## | 100%
#
# mkl_fft-1.0.6        | 150 KB    |            |   0%
# mkl_fft-1.0.6        | 150 KB    | ########## | 100%
#
# scipy-1.1.0          | 18.0 MB   |            |   0%
# scipy-1.1.0          | 18.0 MB   | ##4        |  24%
# scipy-1.1.0          | 18.0 MB   | #####7     |  58%
# scipy-1.1.0          | 18.0 MB   | #######5   |  75%
# scipy-1.1.0          | 18.0 MB   | ########8  |  89%
# scipy-1.1.0          | 18.0 MB   | #########8 |  98%
# scipy-1.1.0          | 18.0 MB   | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########1  |  82%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# intel-openmp-2019.0  | 721 KB    |            |   0%
# intel-openmp-2019.0  | 721 KB    | #########3 |  94%
# intel-openmp-2019.0  | 721 KB    | ########## | 100%
#
# pip-10.0.1           | 1.8 MB    |            |   0%
# pip-10.0.1           | 1.8 MB    | #######7   |  78%
# pip-10.0.1           | 1.8 MB    | ########3  |  84%
# pip-10.0.1           | 1.8 MB    | ########9  |  89%
# pip-10.0.1           | 1.8 MB    | #########5 |  96%
# pip-10.0.1           | 1.8 MB    | ########## | 100%
#
# openssl-1.0.2p       | 3.5 MB    |            |   0%
# openssl-1.0.2p       | 3.5 MB    | #######5   |  76%
# openssl-1.0.2p       | 3.5 MB    | #########1 |  92%
# openssl-1.0.2p       | 3.5 MB    | ########## | 100%
#
# zlib-1.2.11          | 101 KB    |            |   0%
# zlib-1.2.11          | 101 KB    | ########## | 100%
#
# ncurses-6.0          | 920 KB    |            |   0%
# ncurses-6.0          | 920 KB    | #######9   |  79%
# ncurses-6.0          | 920 KB    | #########1 |  92%
# ncurses-6.0          | 920 KB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | ########7  |  88%
# tk-8.6.8             | 3.1 MB    | #########7 |  97%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# ca-certificates-2018 | 124 KB    |            |   0%
# ca-certificates-2018 | 124 KB    | ########## | 100%
#
# numpy-1.15.2         | 47 KB     |            |   0%
# numpy-1.15.2         | 47 KB     | ########## | 100%
#
# readline-7.0         | 1.1 MB    |            |   0%
# readline-7.0         | 1.1 MB    | ########   |  81%
# readline-7.0         | 1.1 MB    | #########7 |  98%
# readline-7.0         | 1.1 MB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########1  |  81%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
|  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  98%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########8 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 |  99%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | #########9 | 100%
# mkl-2019.0           | 204.4 MB  | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | #########7 |  97%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# mkl_random-1.0.1     | 373 KB    |            |   0%
# mkl_random-1.0.1     | 373 KB    | ########## | 100%
#
# scikit-learn-0.20.0  | 5.8 MB    |            |   0%
# scikit-learn-0.20.0  | 5.8 MB    | #######5   |  76%
# scikit-learn-0.20.0  | 5.8 MB    | #########8 |  98%
# scikit-learn-0.20.0  | 5.8 MB    | ########## | 100%
#
# certifi-2018.8.24    | 140 KB    |            |   0%
# certifi-2018.8.24    | 140 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #1         |  12%
# python-3.6.2         | 27.0 MB   | ##8        |  28%
# python-3.6.2         | 27.0 MB   | ####7      |  48%
# python-3.6.2         | 27.0 MB   | ######6    |  67%
# python-3.6.2         | 27.0 MB   | ########   |  80%
# python-3.6.2         | 27.0 MB   | ########9  |  90%
# python-3.6.2         | 27.0 MB   | #########6 |  96%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# wheel-0.31.1         | 62 KB     |            |   0%
# wheel-0.31.1         | 62 KB     | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults (from -r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c3/bf/e20fc299b7e6c12b44e264bb2a745ff70281560cfde8200ddad63570674c/azureml_defaults-0.1.59-py2.py3-none-any.whl
# Collecting azureml-core==0.1.59 (from azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/37/e0/13f91411f0436064f905d14ec38e6b2e9183498703ecf216e0f7a96a4452/azureml_core-0.1.59-py2.py3-none-any.whl (769kB)
# Collecting applicationinsights>=0.11.0 (from azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
# Collecting cryptography (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/59/32/92cade62c645756a83598edf56289e9b19aae5370642a7ce690cd06bc72f/cryptography-2.3.1-cp34-abi3-manylinux1_x86_64.whl (2.1MB)
# Collecting SecretStorage<3.0.0 (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a5/a5/0830cfe34a4cfd0d1c3c8b614ede1edb2aaf999091ac8548dd19cb352e79/SecretStorage-2.3.1.tar.gz
# Collecting azure-storage-blob>=1.1.0 (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/dd/26/45de0cb737aeeeb2fa56cf12ab0042ba64dafd24bcc50bf8c8cdf913a1a6/azure_storage_blob-1.3.1-py2.py3-none-any.whl (77kB)
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d8/92/5411e055a0dc070527121480c3c7a941d3e1302b9866fe6db3af0bde9942/azure_mgmt_storage-3.0.0-py2.py3-none-any.whl (682kB)
# Collecting ndg-httpsclient (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting docker (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/06/0b/ce97eb31058eddaef316973b8299b737ebab0bcb5798fd5a3225d53b4455/docker-3.5.0-py2.py3-none-any.whl (125kB)
# Collecting azure-cli-profile>=2.0.26 (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages
(from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/6f/17/55b974603c16be89c7a7c16bac57b7bce48527bf1bebc3f116f7215176e6/azure_mgmt_authorization-0.50.0-py2.py3-none-any.whl (81kB)
# Collecting backports.tempfile (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting azure-storage-nspkg>=3.0.0 (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b1/e9/0a11f4feefb9c4c2f7e30d4d448e15b32df3adabe370be70aaf4278fbb52/azure_storage_nspkg-3.0.0-py2.py3-none-any.whl
# Collecting msrestazure>=0.4.33 (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a4/48/cfa54772365b4d0b8f3e7af16354db768b0317b3273265b37c14f71b705b/msrestazure-0.5.0-py2.py3-none-any.whl
# Collecting msrest>=0.5.1 (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ad/2a/37b2481fa1a7cd727c07d20cbcb0a3f9bf9dd994930f44dd9770df15c28d/msrest-0.5.5-py2.py3-none-any.whl (47kB)
# Collecting six>=1.11.0 (from azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/67/4b/141a581104b1f6397bfa78ac9d43d8ad29a7ca43ea90a2d863fe3056e86a/six-1.11.0-py2.py3-none-any.whl
# Collecting asn1crypto>=0.21.0 (from cryptography->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
# Collecting cffi!=1.11.3,>=1.7 (from cryptography->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/6d/c0/47db8f624f3e4e2f3f27be03a93379d1ba16a1450a7b1aacfa0366e2c0dd/cffi-1.11.5-cp36-cp36m-manylinux1_x86_64.whl (421kB)
# Collecting idna>=2.1 (from cryptography->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/4b/2a/0276479a4b3caeb8a8c1af2f8e4355746a97fab05a372e4a2c6a6b876165/idna-2.7-py2.py3-none-any.whl (58kB)
# Collecting PyOpenSSL (from ndg-httpsclient->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/96/af/9d29e6bd40823061aea2e0574ccb2fcf72bfd6130ce53d32773ec375458c/pyOpenSSL-18.0.0-py2.py3-none-any.whl (53kB)
# Collecting pyasn1>=0.1.1 (from ndg-httpsclient->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d1/a1/7790cc85db38daa874f6a2e6308131b9953feb1367f2ae2d1123bb93a9f5/pyasn1-0.4.4-py2.py3-none-any.whl (72kB)
# Collecting docker-pycreds>=0.3.0 (from docker->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ea/bf/7e70aeebc40407fbdb96fa9f79fc8e4722ea889a99378303e3bcc73f4ab5/docker_pycreds-0.3.0-py2.py3-none-any.whl
# Collecting websocket-client>=0.32.0 (from docker->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/14/d4/6a8cd4e7f67da465108c7cc0a307a1c5da7e2cdf497330b682069b1d4758/websocket_client-0.53.0-py2.py3-none-any.whl (198kB)
# Collecting azure-cli-command-modules-nspkg>=2.0.0 (from azure-cli-profile>=2.0.26->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e6/c9/cdeeeabc550848e2a07caa66cba28aa057d23b6feaa824ceafd32c3f2226/azure_cli_command_modules_nspkg-2.0.2-py2.py3-none-any.whl
# Collecting azure-mgmt-nspkg>=2.0.0 (from azure-mgmt-resource>=1.2.1->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c9/e3/48b98f929290b0cd0aaa4707ecabb8aaeb267e8ef628af907f1d1c506ec7/azure_mgmt_nspkg-2.0.0-py2.py3-none-any.whl
# Collecting azure-cli-nspkg>=2.0.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a7/85/601ef6484bf7a722daa76a4383c4ccfd4980b74ed6c2895392f53ed210d5/azure_cli_nspkg-3.0.3-py2.py3-none-any.whl
# Collecting jmespath (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting knack==0.4.3 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/77/3d/b83a9fe885b1dd3f33888f9d8875a1b340b8a03daba05c573af99b069f5f/knack-0.4.3-py2.py3-none-any.whl (48kB)
# Collecting colorama>=0.3.9 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/db/c8/7dcf9dbcb22429512708fe3a547f8b6101c0d02137acbd892505aee57adf/colorama-0.3.9-py2.py3-none-any.whl
# Collecting azure-cli-telemetry (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/71/4c/da5ebe9300ecdc850031372f81229383c46a70e83dee8e77f58aa6fd0546/azure_cli_telemetry-1.0.0-py2.py3-none-any.whl
# Collecting PyJWT (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/93/d1/3378cc8184a6524dc92993090ee8b4c03847c567e298305d6cf86987e005/PyJWT-1.6.4-py2.py3-none-any.whl
# Requirement already satisfied: pip in /azureml-envs/azureml_088906b35cdd6596b350e033526a1806/lib/python3.6/site-packages (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1)) (10.0.1)
# Collecting wheel==0.30.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/0c/80/16a85b47702a1f47a63c104c91abdd0a6704ee8ae3b4ce4afc49bc39f9d9/wheel-0.30.0-py2.py3-none-any.whl (49kB)
# Collecting tabulate<=0.8.2,>=0.7.7 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/12/c2/11d6845db5edf1295bc08b2f488cf5937806586afe42936c3f34c097ebdc/tabulate-0.8.2.tar.gz (45kB)
# Collecting pygments (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/02/ee/b6e02dc6529e82b75bb06823ff7d005b141037cb1416b10c6f00fc419dca/Pygments-2.2.0-py2.py3-none-any.whl (841kB)
# Collecting adal>=1.0.2 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/15/2b/8f674c2a20bb2a55f8f1c8fb7a458c9b513409b2cfc42f73e4cbc1ee757e/adal-1.1.0-py2.py3-none-any.whl (51kB)
# Collecting humanfriendly>=4.7 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/fb/34/1e80e4a06020f7dfc7eee11387e400435236f992f80eaa6ed9b3d8252211/humanfriendly-4.16.1-py2.py3-none-any.whl (71kB)
# Collecting paramiko>=2.0.8 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/cf/ae/94e70d49044ccc234bfdba20114fa947d7ba6eb68a2e452d89b920e62227/paramiko-2.4.2-py2.py3-none-any.whl (193kB)
# Collecting argcomplete>=1.8.0 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/31/88/ba8d8684a8a27749250c66ff7c2b408fdbc29b50da61200338ff9b2607bf/argcomplete-1.9.4-py2.py3-none-any.whl
# Collecting antlr4-python3-runtime (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/3e/96/aba01b2948ec67f237cd387c022820835ae0d8db5cab4bd404b351660b5e/antlr4-python3-runtime-4.7.1.tar.gz (111kB)
# Collecting pyyaml~=3.13 (from azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9e/a3/1d13970c3f36777c583f136c136f804d70f500168edc1edea6daa7200769/PyYAML-3.13.tar.gz (270kB)
# Collecting azure-nspkg>=2.0.0 (from azure-graphrbac>=0.40.0->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/cd/a0/76ca6659ae9afd7567fdbb5b9c85e9c9a0b48238cfcacd92525484408f66/azure_nspkg-2.0.0-py2.py3-none-any.whl
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=2.19.1->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_088906b35cdd6596b350e033526a1806/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1)) (2018.8.24)
# Collecting backports.weakref (from backports.tempfile->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/94/e7/c250d122992e1561690d9c0f7856dadb79d61fd4bdd0e598087dce607f6c/requests_oauthlib-1.0.0-py2.py3-none-any.whl
# Collecting pycparser (from cffi!=1.11.3,>=1.7->cryptography->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
# Collecting portalocker==1.2.1 (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/57/41/05e79e5516db1cc0c967b3202388cde729f871c871b0a07bf24ff11adfcf/portalocker-1.2.1-py2.py3-none-any.whl
# Collecting pynacl>=1.0.1 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
# Collecting bcrypt>=3.1.3 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b8/09/905ec939994e2c49dcffff72f823802557f166b3815ea54c1db3671eed42/bcrypt-3.1.4-cp36-cp36m-manylinux1_x86_64.whl (54kB)
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==0.1.59->azureml-defaults->-r /azureml-setup/condaenv.9i3zsjzq.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e6/d1/ddd9cfea3e736399b97ded5c2dd62d1322adef4a72d816f1ed1049d6a179/oauthlib-2.1.0-py2.py3-none-any.whl (121kB)
# Building wheels for collected packages: SecretStorage, pathspec, tabulate, antlr4-python3-runtime, pyyaml, pycparser
#   Running setup.py bdist_wheel for SecretStorage: started
#   Running setup.py bdist_wheel for SecretStorage: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/4e/5b/1b/be8c8a830a0243af85b2946a0aece2c6743d7f7f946977ed67
#   Running setup.py bdist_wheel for pathspec: started
#   Running setup.py bdist_wheel for pathspec: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/45/cb/7e/ce6e6062c69446e39e328170524ca8213498bc66a74c6a210b
#   Running setup.py bdist_wheel for tabulate: started
#   Running setup.py bdist_wheel for tabulate: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/2a/85/33/2f6da85d5f10614cbe5a625eab3b3aebfdf43e7b857f25f829
#   Running setup.py bdist_wheel for antlr4-python3-runtime: started
#   Running setup.py bdist_wheel for antlr4-python3-runtime: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/ef/f6/18/ad300e691236a3408a99edc750484b56e8d6b11b2c38eacb10
#   Running setup.py bdist_wheel for pyyaml: started
#   Running setup.py bdist_wheel for pyyaml: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/ad/da/0c/74eb680767247273e2cf2723482cb9c924fe70af57c334513f
#   Running setup.py bdist_wheel for pycparser: started
#   Running setup.py bdist_wheel for pycparser: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built SecretStorage pathspec tabulate antlr4-python3-runtime pyyaml pycparser
# mkl-random 1.0.1 requires cython, which is not installed.
# Installing collected packages: asn1crypto, pycparser, cffi, six, idna, cryptography, SecretStorage, azure-nspkg, azure-storage-nspkg, azure-common, python-dateutil, chardet, urllib3, requests, azure-storage-common, azure-storage-blob, isodate, oauthlib, requests-oauthlib, msrest, PyJWT, adal, msrestazure, azure-mgmt-storage, PyOpenSSL, pyasn1, ndg-httpsclient, docker-pycreds, websocket-client, docker, azure-mgmt-nspkg, azure-mgmt-resource, azure-cli-nspkg, jmespath, argcomplete, colorama, pyyaml, tabulate, pygments, knack, applicationinsights, portalocker, azure-cli-telemetry, wheel, humanfriendly, pynacl, bcrypt, paramiko, antlr4-python3-runtime, azure-cli-core, azure-cli-command-modules-nspkg, azure-cli-profile, azure-mgmt-keyvault, pathspec, contextlib2, jsonpickle, ruamel.yaml, azure-mgmt-containerregistry, pytz, azure-graphrbac, azure-mgmt-authorization, backports.weakref, backports.tempfile, azureml-core, azureml-defaults
#   Found existing installation: wheel 0.31.1
#     Uninstalling wheel-0.31.1:
#       Successfully uninstalled wheel-0.31.1
# Successfully installed PyJWT-1.6.4 PyOpenSSL-18.0.0 SecretStorage-2.3.1 adal-1.1.0 antlr4-python3-runtime-4.7.1 applicationinsights-0.11.7 argcomplete-1.9.4 asn1crypto-0.24.0 azure-cli-command-modules-nspkg-2.0.2 azure-cli-core-2.0.46 azure-cli-nspkg-3.0.3 azure-cli-profile-2.1.1 azure-cli-telemetry-1.0.0 azure-common-1.1.16 azure-graphrbac-0.40.0 azure-mgmt-authorization-0.50.0 azure-mgmt-containerregistry-2.2.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-nspkg-2.0.0 azure-mgmt-resource-2.0.0 azure-mgmt-storage-3.0.0 azure-nspkg-2.0.0 azure-storage-blob-1.3.1 azure-storage-common-1.3.0 azure-storage-nspkg-3.0.0 azureml-core-0.1.59 azureml-defaults-0.1.59 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.1.4 cffi-1.11.5 chardet-3.0.4 colorama-0.3.9 contextlib2-0.5.5 cryptography-2.3.1 docker-3.5.0 docker-pycreds-0.3.0 humanfriendly-4.16.1 idna-2.7 isodate-0.6.0 jmespath-0.9.3 jsonpickle-1.0 knack-0.4.3 msrest-0.5.5 msrestazure-0.5.0 ndg-httpsclient-0.5.1 oauthlib-2.1.0 paramiko-2.4.2 pathspec-0.5.9 portalocker-1.2.1 pyasn1-0.4.4 pycparser-2.19 pygments-2.2.0 pynacl-1.3.0 python-dateutil-2.7.3 pytz-2018.5 pyyaml-3.13 requests-2.19.1 requests-oauthlib-1.0.0 ruamel.yaml-0.15.51 six-1.11.0 tabulate-0.8.2 urllib3-1.23 websocket-client-0.53.0 wheel-0.30.0
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_088906b35cdd6596b350e033526a1806
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
#  ---> 529c79ef8328
# Removing intermediate container 11f4482854e6
# Step 9/13 : ENV PATH /azureml-envs/azureml_088906b35cdd6596b350e033526a1806/bin:$PATH
#  ---> Running in ecf5c2dc6ab6
#  ---> 9fc15cccc7a7
# Removing intermediate container ecf5c2dc6ab6
# Step 10/13 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_088906b35cdd6596b350e033526a1806/lib:$LD_LIBRARY_PATH
#  ---> Running in 98a636dc2d4e
#  ---> 3221db260168
# Removing intermediate container 98a636dc2d4e
# Step 11/13 : COPY azureml-setup/spark_cache.py azureml-setup/log4j.properties /azureml-setup/
#  ---> 8b6612a84937
# Step 12/13 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "https://mmlspark.azureedge.net/maven" "--packages" "com.microsoft.ml.spark:mmlspark_2.11:0.12" "--conf" "spark.app.name=Azure ML Experiment" "--conf" "spark.yarn.maxAppAttempts=1" "--driver-java-options" "-Dlog4j.configuration=file:./azureml-setup/log4j.properties" "--conf" "spark.eventLog.enabled=true" "--conf" "spark.eventLog.dir=./azureml-logs" /azureml-setup/spark_cache.py'; fi
#  ---> Running in 69eb01715f69
#  ---> 9feae9ad32b2
# Removing intermediate container 69eb01715f69
# Step 13/13 : CMD bash
#  ---> Running in 82cd04bc0963
#  ---> 6d44d1530841
# Removing intermediate container 82cd04bc0963
# Successfully built 6d44d1530841
# Successfully tagged pekamlwoacrjcvuohfw.azurecr.io/azureml/azureml_f317120a1fc82ac7884c9fb0444dfdec:latest
# Removing any dangling images
# Docker build took 210.85830521583557 seconds
# Logging into acr pekamlwoacrjcvuohfw.azurecr.io to do docker push
# Login Succeeded
# Pushing image azureml/azureml_f317120a1fc82ac7884c9fb0444dfdec to acr pekamlwoacrjcvuohfw.azurecr.io
# The push refers to a repository [pekamlwoacrjcvuohfw.azurecr.io/azureml/azureml_f317120a1fc82ac7884c9fb0444dfdec]
# a63de82d0993: Preparing
# 067295afa7c0: Preparing
# 0fc6a8ed73c1: Preparing
# 3f5cf02c3d3a: Preparing
# 76e285cd3733: Preparing
# f41953166959: Preparing
# 392a009de2b3: Preparing
# 1db0da3b3d01: Preparing
# e46e9e8b1cbf: Preparing
# 75b79e19929c: Preparing
# 4775b2f378bb: Preparing
# 883eafdbe580: Preparing
# 19d043c86cbc: Preparing
# 8823818c4748: Preparing
# f41953166959: Waiting
# 392a009de2b3: Waiting
# 1db0da3b3d01: Waiting
# e46e9e8b1cbf: Waiting
# 75b79e19929c: Waiting
# 4775b2f378bb: Waiting
# 883eafdbe580: Waiting
# 19d043c86cbc: Waiting
# 8823818c4748: Waiting
# 0fc6a8ed73c1: Pushed
# 76e285cd3733: Pushed
# 3f5cf02c3d3a: Pushed
# a63de82d0993: Pushed
# e46e9e8b1cbf: Pushed
# 75b79e19929c: Pushed
# 4775b2f378bb: Pushed
# 883eafdbe580: Pushed
# 19d043c86cbc: Pushed
# f41953166959: Pushed
# 1db0da3b3d01: Pushed
# 8823818c4748: Pushed
# 392a009de2b3: Pushed
# 067295afa7c0: Pushed
# latest: digest: sha256:6178b1d1fd225883fbf6b810e03c0f252fd6f7e37df468e20c5b28ab977ecea4 size: 3246
# Removing login credentials for pekamlwoacrjcvuohfw.azurecr.io
# Docker push took 221.99887704849243 seconds
# Not logged in to pekamlwoacrjcvuohfw.azurecr.io
# Docker logout(s) took 0.030462265014648438 seconds
# Removing image with name pekamlwoacrjcvuohfw.azurecr.io/azureml/azureml_f317120a1fc82ac7884c9fb0444dfdec
# Untagged: pekamlwoacrjcvuohfw.azurecr.io/azureml/azureml_f317120a1fc82ac7884c9fb0444dfdec:latest
# Untagged: pekamlwoacrjcvuohfw.azurecr.io/azureml/azureml_f317120a1fc82ac7884c9fb0444dfdec@sha256:6178b1d1fd225883fbf6b810e03c0f252fd6f7e37df468e20c5b28ab977ecea4
# Deleted: sha256:6d44d1530841b1a75eaf5e237ef2b03d0dd4f14821dd0b8d2696af0b8b741eab
# Deleted: sha256:9feae9ad32b267b6322602b544a0033c22fc95d59cd03ba6ad6c0b0b3fea0155
# Deleted: sha256:8b6612a849375f9cebc11b0513e10fd6adda333e67d958a3b8e4ff731af54dc3
# Deleted: sha256:a91136982c00383457c910838307a7f7739b8188a01d06c1ade7a15175514034
# Deleted: sha256:3221db2601684f45e961c92b5939953357150bf700aafd0682b76471a079b9e4
# Deleted: sha256:9fc15cccc7a7ed7ff912f15495f7dc152419cdb41367da546880374d48fbcbea
# Deleted: sha256:529c79ef8328f15e8e5beb9249ae7dcb1fd722512caeee414d13e505efa2c876
# Deleted: sha256:6d185a2f52fcb2f625ea0b932d84b047836e0356e70afdbcaa0caca65365bf63
# Deleted: sha256:54ad0858172d2358119740ac59930be4c81a96e83fd358a5d5f74739366ca263
# Deleted: sha256:fd758bd105797c56db5b83f4c621c798fc2569b311e3edebc7936689e268d952
# Deleted: sha256:b4e84b7861bc1cf1f626a3f9d86f52be5ca6e0ce97425fecf8aef5c6af0ad9fe
# Deleted: sha256:d211a1d31ffa6596a50030d3079d56ee2a3814d32bde69c53457ee3ad0f4c4ab
# Deleted: sha256:c98bcea37d791ba53643fb1d3021e38c75579e83dc101557a48916bff14abe8c
# Deleted: sha256:bcc213e75c917a527c32a469fb4b8326a8e28e0f80cfd87e146a7f1e84b485f5
# Deleted: sha256:54b4485ee75713c196ae9fa3cb1580ef408b12b4853ca02b94196e7c9a93e367
# Deleted: sha256:d2fe872bc5e523284fae8d37eea282889f87514e0234585ea103b2db0402f8b3
# Deleted: sha256:c6c26b5ee9de9b63051f7524c4e0ab32116cb1bec4558ee45b3f5db89ed94968
# Total task took 434.8789463043213 secs
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# Uploading experiment status to history service.
# Adding run profile attachment azureml-logs/60_control_log.txt
# Uploading experiment status to history service.
# Adding run profile attachment azureml-logs/80_driver_log.txt
#
# Streaming azureml-logs/80_driver_log.txt
# ========================================
#
# /azureml-envs/azureml_088906b35cdd6596b350e033526a1806/lib/python3.6/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# Data folder: /mnt/batch/tasks/shared/LS_root/jobs/pekbatchaid1538295631/azureml/aks-compute-trial_1538376894240/mounts/pekdatastore/mnist
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)
# Train a logistic regression model with regularizaion rate of 0.8
# /azureml-envs/azureml_088906b35cdd6596b350e033526a1806/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /azureml-envs/azureml_088906b35cdd6596b350e033526a1806/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:459: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Predict the test set
# Accuracy is 0.9204
#
#
# The experiment completed successfully. Finalizing run...
# Logging experiment finalizing status in history service
#
# Execution Summary
# =================
# RunId: aks-compute-trial_1538376894240
# {'runId': 'aks-compute-trial_1538376894240',
#  'target': 'pekbatchai',
#  'status': 'Finalizing',
#  'startTimeUtc': '2018-10-01T07:02:58.49432Z',
#  'properties': {'azureml.runsource': 'experiment',
#   'ContentSnapshotId': 'b164ca46-f397-4c7f-9b02-a030123fd43c'},
#  'runDefinition': {'Script': 'train.py',
#   'Arguments': ['--data-folder',
#    '$AZUREML_DATAREFERENCE_pekdatastore',
#    '--regularization',
#    '0.8'],
#   'Framework': 0,
#   'Target': 'pekbatchai',
#   'DataReferences': {'pekdatastore': {'DataStoreName': 'pekdatastore',
#     'Mode': 'Mount',
#     'PathOnDataStore': None,
#     'PathOnCompute': None,
#     'Overwrite': False}},
#   'JobName': None,
#   'AutoPrepareEnvironment': True,
#   'MaxRunDurationSeconds': None,
#   'Environment': {'Python': {'InterpreterPath': 'python',
#     'UserManagedDependencies': False,
#     'CondaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults']},
#       'scikit-learn']},
#     'CondaDependenciesFile': None},
#    'EnvironmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'Docker': {'BaseImage': 'mcr.microsoft.com/azureml/base:0.1.3',
#     'Enabled': True,
#     'SharedVolumes': True,
#     'GpuSupport': False,
#     'Arguments': [],
#     'BaseImageRegistry': {'Address': None,
#      'Username': None,
#      'Password': None}},
#    'Spark': {'Repositories': ['https://mmlspark.azureedge.net/maven'],
#     'Packages': [{'Group': 'com.microsoft.ml.spark',
#       'Artifact': 'mmlspark_2.11',
#       'Version': '0.12'}],
#     'PrecachePackages': True}},
#   'History': {'OutputCollection': True},
#   'Spark': {'Configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'BatchAi': {'NodeCount': 1},
#   'Tensorflow': {'WorkerCount': 2, 'ParameterServerCount': 1},
#   'Mpi': {'ProcessCountPerNode': 1},
#   'Hdi': {'YarnDeployMode': 2},
#   'ContainerInstance': {'Region': None, 'CpuCores': 1, 'MemoryGb': 4},
#   'ExposedPorts': None,
#   'PrepareEnvironment': None},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://pekamlwostoragesxxxkccr.blob.core.windows.net/azureml/ExperimentRun/aks-compute-trial_1538376894240/azureml-logs/20_image_build_log.txt?sv=2017-04-17&sr=b&sig=VPt1sq7hkqkVgbWid%2FFYZ1ebVytxII8l0yUhgIyjBw4%3D&st=2018-10-01T07%3A28%3A55Z&se=2018-10-01T15%3A38%3A55Z&sp=r',
#   'azureml-logs/60_control_log.txt': 'https://pekamlwostoragesxxxkccr.blob.core.windows.net/azureml/ExperimentRun/aks-compute-trial_1538376894240/azureml-logs/60_control_log.txt?sv=2017-04-17&sr=b&sig=2qL44yGbtLhE0hiU%2FUtkozFZ%2B66x%2FZIs78JDFeJeB8Y%3D&st=2018-10-01T07%3A28%3A55Z&se=2018-10-01T15%3A38%3A55Z&sp=r',
#   'azureml-logs/80_driver_log.txt': 'https://pekamlwostoragesxxxkccr.blob.core.windows.net/azureml/ExperimentRun/aks-compute-trial_1538376894240/azureml-logs/80_driver_log.txt?sv=2017-04-17&sr=b&sig=TSo6l%2FK062%2BK75skSr9VjymEUtE%2FJR6zyub0WjhvFrc%3D&st=2018-10-01T07%3A28%3A55Z&se=2018-10-01T15%3A38%3A55Z&sp=r'}}

# %%
print(run.get_metrics())
print(run.get_file_names())
# Out:
# {}
# []

# %%
# register model 
model = run.register_model(model_name='batchai_sklearn_mnist', model_path='outputs/sklearn_mnist_model.pkl')
print(model.name, model.id, model.version, sep = '\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6b7622b684a2> in <module>()
#       1 # register model
# ----> 2 model = run.register_model(model_name='batchai_sklearn_mnist', model_path='outputs/sklearn_mnist_model.pkl')
#       3 print(model.name, model.id, model.version, sep = '\t')
#
# NameError: name 'run' is not defined
