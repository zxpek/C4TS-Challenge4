# %% [markdown]
# # Training with custom scripts
#
# This notebook is meant for the scenario where JMC's data science team might bring their own scripts for training, potentially their own custom libraries. In this case, we will use scikit learn to simulate a custom library that might be used.
#
# ## Setting up AzureML Experiment

# %%
import azureml.core
from azureml.core import Workspace
from azureml.core import Experiment
import os
import shutil

ws = Workspace.from_config()
exp_name = 'c4ts-customlib'
exp = Experiment(workspace = ws, name = exp_name)

project_folder = './{}'.format(exp_name)
os.makedirs(project_folder, exist_ok=True)
shutil.copy('AssetData_Historical.csv', project_folder)
# Out:
# Found the config file in: C:\Users\zhpek\Desktop\C4TS-Challenge4\aml_config\config.json
# './c4ts-customlib\\AssetData_Historical.csv'

# %% [markdown]
# ## Custom Dataprep scripts
#
# We make the same steps we do with the AutoML use case. In this case, we make a $\texttt{prepare}$ function to simplify and clean up the training script.

# %%
# %%writefile ./c4ts-customlib/utils.py

import pandas as pd
import numpy as np
from sklearn.decomposition import PCA


def cleanLongLat(l):
    split = l.str.split(',', expand=True)
    split = (split[0]+'.'+[i if len(i)>1 else i+'0' for i in split[1]]).astype(float)
    return(split)
    
class scaler:
    def __init__(self, x = None):
        if type(x) == pd.core.frame.DataFrame:
            self.fit(x)
        elif x == None:
            self.x = None
            self.mean = None
            self.var = None
        else:
            raise Exception('Require pandas.DF input')


    def fit(self, x):
        self.x = x
        self.mean = x.mean()
        self.var = x.var()

    def scale(self, new_x):
        result = (new_x - self.mean) / np.sqrt(self.var)
        return (result)
    
def prepare(X, fit = False, scaler_obj = None, pca_obj = None):
    
    if fit:
        s = scaler(X)
        pca = PCA()
        X_ = s.scale(X)
        X_ = pca.fit_transform(X_)
        X_ = X_[:,:10]
        
        return(X_, s, pca)
    else:
        if scaler_obj == None or pca_obj == None:
            raise Exception('Non fitting requires scaler/pca obj')
        X_ = pca_obj.transform(scaler_obj.scale(X))[:,:10]
        return X_
# Out:
# Overwriting ./c4ts-customlib/utils.py

# %% [markdown]
# ## Training Script
#
# We use scikit learn's GB Classifier as a quick example with grid search over a number of trees and learning rate.

# %%
# %%writefile ./c4ts-customlib/train.py

import os
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from azureml.core.run import Run
from sklearn.externals import joblib
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier

from utils import *
    
os.makedirs('./outputs', exist_ok=True)

# Data Preparation
df = pd.read_csv('AssetData_Historical.csv')
df.drop(['Machine_ID', 'District'], axis=1, inplace=True)
df['Latitude'] = cleanLongLat(df['Latitude'])
df['Longitude'] = cleanLongLat(df['Longitude'])
X = df.drop('Failure_NextHour', 1)
y = df['Failure_NextHour']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, stratify = y)

X_prep, s, pca= prepare(X_train, fit = True)

#run = Run.get_context()

data = {"train": {"X": X_train, "y": y_train},
        "test": {"X": X_test, "y": y_test}}

param_grid = {'learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3],
              'n_estimators': [100, 200, 300, 400, 500]
}

model = GradientBoostingClassifier(loss = 'exponential')
kf = StratifiedKFold(n_splits = 5, shuffle = True)
gridsearch = GridSearchCV(model, param_grid, 
                          scoring = 'f1_weighted',
                          n_jobs = -1,
                          cv = kf)
weights = y_train * 3 + 1
result = gridsearch.fit(X_prep, y_train, sample_weight = weights)

run.log('bestScore', result.best_score_)
run.log('bestParam', result.best_params_)
run.log('valMean', result.cv_results_['mean_test_score'])
run.log('valStd', result.cv_results_['std_test_score'])
run.log('valParams', result.cv_results_['params'])
run.log('FeatureImportance', result.)

#################
#Fit Final Model#
#################

X, s, pca = prepare(X, fit = True)
best_model = result.estimator.fit(X, y, sample_weight = y*4 + 1)

pickle.dump(s, open('./outputs/scaler.pkl', 'wb'))
pickle.dump(pca,open('./outputs/pca_transform.pkl','wb'))

import time
model_name = 'GBT_{}'.format(time.time())
with open(model_name, 'wb') as f:
    joblib.dump(value = best_model, filename = './outputs/{}.pkl'.format(model_name))
# Out:
# Overwriting ./c4ts-customlib/train.py

# %%
from azureml.core.runconfig import RunConfiguration
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.compute import ComputeTarget#, AmlCompute

cpu_cluster = ComputeTarget(workspace=ws, name= "pekamlcompute")
run_config = RunConfiguration(framework="python")
run_config.target = cpu_cluster.name
run_config.environment.docker.enabled = True
run_config.environment.python.conda_dependencies = CondaDependencies.create(conda_packages=['scikit-learn', 'pandas','numpy'])

from azureml.core import Run
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory=project_folder, 
                      script='train.py', 
                      run_config=run_config) 
run = exp.submit(config=src)
run
# Out:
# Run(Experiment: c4ts-customlib,
# Id: c4ts-customlib_1548055757348,
# Type: azureml.scriptrun,
# Status: Starting)

# %%
# %%time
# Shows output of the run on stdout.
run.wait_for_completion(show_output=True)
# Out:
# RunId: c4ts-customlib_1548055757348
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2019/01/21 07:29:28 Using acb_vol_23d5d435-33ca-4827-bdcf-840d3eaba5c6 as the home volume
# 2019/01/21 07:29:28 Creating Docker network: acb_default_network, driver: 'bridge'
# 2019/01/21 07:29:28 Successfully set up Docker network: acb_default_network
# 2019/01/21 07:29:28 Setting up Docker configuration...
# 2019/01/21 07:29:29 Successfully set up Docker configuration
# 2019/01/21 07:29:29 Logging in to registry: pekamlws1688522486.azurecr.io
# 2019/01/21 07:29:30 Successfully logged into pekamlws1688522486.azurecr.io
# 2019/01/21 07:29:30 Executing step ID: acb_step_0. Working directory: '', Network: 'acb_default_network'
# 2019/01/21 07:29:30 Obtaining source code and scanning for dependencies...
# 2019/01/21 07:29:31 Successfully obtained source code and scanned for dependencies
# 2019/01/21 07:29:31 Launching container with name: acb_step_0
# Sending build context to Docker daemon  3.489MB
#
# Step 1/12 : FROM mcr.microsoft.com/azureml/base:0.2.0
# 0.2.0: Pulling from azureml/base
# 3b37166ec614: Pulling fs layer
# 504facff238f: Pulling fs layer
# ebbcacd28e10: Pulling fs layer
# c7fb3351ecad: Pulling fs layer
# 2e3debadcbf7: Pulling fs layer
# 7ff5eaad8a49: Pulling fs layer
# 8697dd9e92dc: Pulling fs layer
# 112403772eb3: Pulling fs layer
# 0431a9485aa5: Pulling fs layer
# a8ab5d81aeba: Pulling fs layer
# c7fb3351ecad: Waiting
# 2e3debadcbf7: Waiting
# 7ff5eaad8a49: Waiting
# 8697dd9e92dc: Waiting
# 112403772eb3: Waiting
# 0431a9485aa5: Waiting
# a8ab5d81aeba: Waiting
# 504facff238f: Verifying Checksum
# 504facff238f: Download complete
# ebbcacd28e10: Download complete
# c7fb3351ecad: Verifying Checksum
# c7fb3351ecad: Download complete
# 2e3debadcbf7: Verifying Checksum
# 2e3debadcbf7: Download complete
# 7ff5eaad8a49: Verifying Checksum
# 7ff5eaad8a49: Download complete
# 3b37166ec614: Download complete
# 8697dd9e92dc: Verifying Checksum
# 8697dd9e92dc: Download complete
# 0431a9485aa5: Verifying Checksum
# 0431a9485aa5: Download complete
# 3b37166ec614: Pull complete
# 504facff238f: Pull complete
# ebbcacd28e10: Pull complete
# c7fb3351ecad: Pull complete
# 2e3debadcbf7: Pull complete
# 7ff5eaad8a49: Pull complete
# 112403772eb3: Verifying Checksum
# 112403772eb3: Download complete
# a8ab5d81aeba: Verifying Checksum
# a8ab5d81aeba: Download complete
# 8697dd9e92dc: Pull complete
# 112403772eb3: Pull complete
# 0431a9485aa5: Pull complete
# a8ab5d81aeba: Pull complete
# Digest: sha256:bddfac8e9a4406c13f314cefefa24f3f67e959a8d8b26067096f7ade6f02ef12
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:0.2.0
#  ---> b588362a9d48
# Step 2/12 : USER root
#  ---> Running in dfb072adc455
# Removing intermediate container dfb072adc455
#  ---> ab4a0c213312
# Step 3/12 : RUN mkdir -p $HOME/.cache
#  ---> Running in 6a7dd8afee05
# Removing intermediate container 6a7dd8afee05
#  ---> e838959bb1c7
# Step 4/12 : WORKDIR /
#  ---> Running in 1927b1487d54
# Removing intermediate container 1927b1487d54
#  ---> 24a689d808a7
# Step 5/12 : COPY azureml-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 7ae47f14801f
# Step 6/12 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.0; then conda install conda==4.4.11; fi
#  ---> Running in 93dc352469ec
# Removing intermediate container 93dc352469ec
#  ---> 2fca0ea2949b
# Step 7/12 : COPY azureml-setup/mutated_conda_dependencies.yml azureml-setup/mutated_conda_dependencies.yml
#  ---> 308f48c13345
# Step 8/12 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978 -f azureml-setup/mutated_conda_dependencies.yml && ldconfig
#  ---> Running in c3d3fba617d8
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.5.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# certifi-2018.11.29   | 146 KB    |            |   0%
# certifi-2018.11.29   | 146 KB    | ########## | 100%
#
# mkl-2019.1           | 204.6 MB  |            |   0%
# mkl-2019.1           | 204.6 MB  | 3          |   4%
# mkl-2019.1           | 204.6 MB  | 7          |   8%
# mkl-2019.1           | 204.6 MB  | #1         |  12%
# mkl-2019.1           | 204.6 MB  | #5         |  16%
# mkl-2019.1           | 204.6 MB  | ##         |  20%
# mkl-2019.1           | 204.6 MB  | ##4        |  24%
# mkl-2019.1           | 204.6 MB  | ##8        |  28%
# mkl-2019.1           | 204.6 MB  | ###2       |  32%
# mkl-2019.1           | 204.6 MB  | ###6       |  36%
# mkl-2019.1           | 204.6 MB  | ####       |  40%
# mkl-2019.1           | 204.6 MB  | ####4      |  44%
# mkl-2019.1           | 204.6 MB  | ####8      |  48%
# mkl-2019.1           | 204.6 MB  | #####2     |  52%
# mkl-2019.1           | 204.6 MB  | #####6     |  56%
# mkl-2019.1           | 204.6 MB  | ######     |  60%
# mkl-2019.1           | 204.6 MB  | ######4    |  64%
# mkl-2019.1           | 204.6 MB  | ######8    |  68%
# mkl-2019.1           | 204.6 MB  | #######2   |  72%
# mkl-2019.1           | 204.6 MB  | #######6   |  76%
# mkl-2019.1           | 204.6 MB  | #######9   |  79%
# mkl-2019.1           | 204.6 MB  | ########1  |  81%
# mkl-2019.1           | 204.6 MB  | ########2  |  83%
# mkl-2019.1           | 204.6 MB  | ########3  |  84%
# mkl-2019.1           | 204.6 MB  | ########4  |  84%
# mkl-2019.1           | 204.6 MB  | ########4  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  85%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########5  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  86%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########6  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  87%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########7  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  88%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########8  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  89%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | ########9  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  90%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########  |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  91%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########1 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  92%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########2 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  93%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########3 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  94%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########4 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  95%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########5 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  96%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########6 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  97%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########7 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  98%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########8 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 |  99%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | #########9 | 100%
# mkl-2019.1           | 204.6 MB  | ########## | 100%
# intel-openmp-2019.1  | 885 KB    |            |   0%
# intel-openmp-2019.1  | 885 KB    | #########1 |  92%
# intel-openmp-2019.1  | 885 KB    | ########## | 100%
#
# numpy-base-1.15.4    | 4.3 MB    |            |   0%
# numpy-base-1.15.4    | 4.3 MB    | #######6   |  76%
# numpy-base-1.15.4    | 4.3 MB    | #########3 |  93%
# numpy-base-1.15.4    | 4.3 MB    | ########## | 100%
#
# ca-certificates-2018 | 123 KB    |            |   0%
# ca-certificates-2018 | 123 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########2  |  82%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# scikit-learn-0.20.2  | 5.7 MB    |            |   0%
# scikit-learn-0.20.2  | 5.7 MB    | #######5   |  76%
# scikit-learn-0.20.2  | 5.7 MB    | #########5 |  95%
# scikit-learn-0.20.2  | 5.7 MB    | ########## | 100%
#
# libgcc-ng-8.2.0      | 7.6 MB    |            |   0%
# libgcc-ng-8.2.0      | 7.6 MB    | #######5   |  76%
# libgcc-ng-8.2.0      | 7.6 MB    | #########8 |  98%
# libgcc-ng-8.2.0      | 7.6 MB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | ##         |  21%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | #########2 |  92%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# mkl_random-1.0.2     | 407 KB    |            |   0%
# mkl_random-1.0.2     | 407 KB    | ########## | 100%
#
# setuptools-40.6.3    | 625 KB    |            |   0%
# setuptools-40.6.3    | 625 KB    | #########2 |  93%
# setuptools-40.6.3    | 625 KB    | ########## | 100%
#
# libstdcxx-ng-8.2.0   | 2.9 MB    |            |   0%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #######8   |  79%
# libstdcxx-ng-8.2.0   | 2.9 MB    | ########## | 100%
#
# python-dateutil-2.7. | 275 KB    |            |   0%
# python-dateutil-2.7. | 275 KB    | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# six-1.12.0           | 22 KB     |            |   0%
# six-1.12.0           | 22 KB     | ########## | 100%
#
# pip-18.1             | 1.8 MB    |            |   0%
# pip-18.1             | 1.8 MB    | #######8   |  78%
# pip-18.1             | 1.8 MB    | #########6 |  97%
# pip-18.1             | 1.8 MB    | ########## | 100%
#
# readline-7.0         | 1.1 MB    |            |   0%
# readline-7.0         | 1.1 MB    | ########8  |  88%
# readline-7.0         | 1.1 MB    | ########## | 100%
#
# scipy-1.1.0          | 17.7 MB   |            |   0%
# scipy-1.1.0          | 17.7 MB   | ###3       |  33%
# scipy-1.1.0          | 17.7 MB   | #######5   |  75%
# scipy-1.1.0          | 17.7 MB   | #########4 |  95%
# scipy-1.1.0          | 17.7 MB   | ########## | 100%
#
# numpy-1.15.4         | 47 KB     |            |   0%
# numpy-1.15.4         | 47 KB     | ########## | 100%
#
# pandas-0.23.4        | 10.1 MB   |            |   0%
# pandas-0.23.4        | 10.1 MB   | ######8    |  69%
# pandas-0.23.4        | 10.1 MB   | ########9  |  89%
# pandas-0.23.4        | 10.1 MB   | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# ncurses-6.0          | 920 KB    |            |   0%
# ncurses-6.0          | 920 KB    | #######9   |  79%
# ncurses-6.0          | 920 KB    | #########2 |  93%
# ncurses-6.0          | 920 KB    | ########## | 100%
#
# mkl_fft-1.0.10       | 170 KB    |            |   0%
# mkl_fft-1.0.10       | 170 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #7         |  17%
# python-3.6.2         | 27.0 MB   | ####1      |  42%
# python-3.6.2         | 27.0 MB   | #######5   |  75%
# python-3.6.2         | 27.0 MB   | #########2 |  93%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########4  |  84%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# openssl-1.0.2p       | 3.5 MB    |            |   0%
# openssl-1.0.2p       | 3.5 MB    | #######5   |  76%
# openssl-1.0.2p       | 3.5 MB    | #########7 |  97%
# openssl-1.0.2p       | 3.5 MB    | ########## | 100%
#
# pytz-2018.9          | 260 KB    |            |   0%
# pytz-2018.9          | 260 KB    | ########9  |  90%
# pytz-2018.9          | 260 KB    | ########## | 100%
#
# wheel-0.32.3         | 35 KB     |            |   0%
# wheel-0.32.3         | 35 KB     | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults==1.0.2 (from -r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bb/4e/27a93da1484f06043f0a6b4d4f3e5ed7212c513eb0d2021cb434c4b2a29d/azureml_defaults-1.0.2-py2.py3-none-any.whl
# Collecting applicationinsights>=0.11.0 (from azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
# Collecting azureml-core==1.0.2.* (from azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f5/ce/3443d87ba4735de037003413063b7d5d77b00543b787c495b0ab682be254/azureml_core-1.0.2-py2.py3-none-any.whl (651kB)
# Collecting azure-common>=1.1.12 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a5/b2/12c7c906a560e1f0171664c28cadfd989ecf874562cc9c21beea851bf7d1/azure_common-1.1.17-py2.py3-none-any.whl
# Collecting azure-storage-nspkg>=3.0.0 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ba/f6/054ace7b01c6c21b3b95a83c3997f7d6539d939a2c08c4f27f779128a030/azure_storage_nspkg-3.1.0-py2.py3-none-any.whl
# Collecting azure-mgmt-resource>=1.2.1 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/2b/2e/e79a278bedfc21308ab0c632759cfda5d7ff02d62260bcc4632449937dcf/azure_mgmt_resource-2.1.0-py2.py3-none-any.whl (757kB)
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d9/87/ab44b9d9627ff91825ba5f5a39092ebfe97a90679008609db4c479036591/azure_mgmt_storage-3.1.1-py2.py3-none-any.whl (696kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/60/c7/99b33c53cf3f20a97a4c4bfd3ab66dcc93d99da0a97cc9597aa36ae6bb62/cryptography-2.4.2-cp34-abi3-manylinux1_x86_64.whl (2.1MB)
# Collecting msrest>=0.5.1 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/eb/96/1cf56e4cfd221b7f6eb6ab096dc23b0d21361393f0784276531e49b0b2a1/msrest-0.6.4-py2.py3-none-any.whl (81kB)
# Collecting PyJWT (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting azure-mgmt-authorization>=0.40.0 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a1/71/9a20913e92771b3c23564f1bea54d376d09fb30a75585087c70b769d75c8/azure_mgmt_authorization-0.51.1-py2.py3-none-any.whl (111kB)
# Collecting msrestazure>=0.4.33 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/46/ba/7870308e3d3b4b3956880eed2df20669a5690436793e6fc1442c8b73e01c/msrestazure-0.6.0-py2.py3-none-any.whl
# Collecting docker (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7e/3c/b610f22b170b0f8fe4d8f78974878e116562389f666f99e6549567eb9d87/docker-3.7.0-py2.py3-none-any.whl (133kB)
# Collecting urllib3<1.24,>=1.23 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bd/c9/6fdd990019071a4a32a5e7cb78a1d92c53851ef4f56f62a3486e6a7d8ffb/urllib3-1.23-py2.py3-none-any.whl (133kB)
# Collecting azure-graphrbac>=0.40.0 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/da/a8/3d3d6fe8458b2b07bad10195c79928ea9ba87b5cc0c08903b387dd27c6f0/azure_graphrbac-0.53.0-py2.py3-none-any.whl (108kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib/python3.6/site-packages (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1)) (2018.9)
# Collecting azure-mgmt-containerregistry>=2.0.0 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/4e/93/982bdd8f38379405beab963ee2abf1ab42a826a57cc2157228216cfc62e4/azure_mgmt_containerregistry-2.6.0-py2.py3-none-any.whl (501kB)
# Collecting azure-storage-common>=1.1.0 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/73/84/025ac436a6a1d5516d1a67887d7122b3b2ea04ba6b2d2c46fe949accb62b/azure_storage_common-1.4.0-py2.py3-none-any.whl (46kB)
# Collecting azure-mgmt-keyvault>=0.40.0 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
# Collecting requests>=2.19.1 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl (57kB)
# Collecting azure-cli-profile>=2.0.26 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c2/d3/fdc722a1b61857250a76027d6d73a50182c6d85132ddd65600a8993574ce/azure_cli_profile-2.1.2-py2.py3-none-any.whl
# Collecting jsonpickle (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ca/ce/97404d5aeb58e6155c216825c81b50f6eca8a5345c582317ae48391878f8/jsonpickle-1.0-py2.py3-none-any.whl
# Collecting backports.tempfile (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting SecretStorage<3.0.0 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a5/a5/0830cfe34a4cfd0d1c3c8b614ede1edb2aaf999091ac8548dd19cb352e79/SecretStorage-2.3.1.tar.gz
# Collecting ruamel.yaml<=0.15.51,>=0.15.35 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d2/7f/9bb3ba89ceab600c4a0ea75d638ea945215ca3458ac6528e0e39fa3254e4/ruamel.yaml-0.15.51-cp36-cp36m-manylinux1_x86_64.whl (640kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib/python3.6/site-packages (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1)) (1.12.0)
# Collecting azure-cli-core>=2.0.38 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/13/d9/db78eb6ca9272ab486bdf1327fdca87a8b8915654efee0ab56f3837238b1/azure_cli_core-2.0.55-py2.py3-none-any.whl (107kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib/python3.6/site-packages (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1)) (2.7.5)
# Collecting ndg-httpsclient (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting pathspec (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/84/2a/bfee636b1e2f7d6e30dd74f49201ccfa5c3cf322d44929ecc6c137c486c5/pathspec-0.5.9.tar.gz
# Collecting azure-storage-blob>=1.1.0 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f7/b7/9b20c39bf411e896d110d01f2551e6e7b397fde6eb06b07293fe29705d13/azure_storage_blob-1.4.0-py2.py3-none-any.whl (75kB)
# Collecting contextlib2 (from azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a2/71/8273a7eeed0aff6a854237ab5453bc9aa67deb49df4832801c21f0ff3782/contextlib2-0.5.5-py2.py3-none-any.whl
# Collecting azure-nspkg>=2.0.0 (from azure-storage-nspkg>=3.0.0->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Collecting cffi!=1.11.3,>=1.7 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/6d/c0/47db8f624f3e4e2f3f27be03a93379d1ba16a1450a7b1aacfa0366e2c0dd/cffi-1.11.5-cp36-cp36m-manylinux1_x86_64.whl (421kB)
# Collecting asn1crypto>=0.21.0 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
# Collecting idna>=2.1 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1)) (2018.11.29)
# Collecting adal<2.0.0,>=0.6.0 (from msrestazure>=0.4.33->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/2d/2f/14882b8dae0977e85577abde3065c141fb94dbb242adfb80e21797e4f7c9/adal-1.2.0-py2.py3-none-any.whl (52kB)
# Collecting websocket-client>=0.32.0 (from docker->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/26/2d/f749a5c82f6192d77ed061a38e02001afcba55fe8477336d26a950ab17ce/websocket_client-0.54.0-py2.py3-none-any.whl (200kB)
# Collecting docker-pycreds>=0.4.0 (from docker->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting azure-mgmt-nspkg>=2.0.0 (from azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b3/c2/af4b47845f27dc7d206ed4908b9e580f8bc94a4b2f3956a0d87c40719d90/azure_mgmt_nspkg-3.0.2-py3-none-any.whl
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=2.19.1->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting azure-cli-command-modules-nspkg>=2.0.0 (from azure-cli-profile>=2.0.26->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e6/c9/cdeeeabc550848e2a07caa66cba28aa057d23b6feaa824ceafd32c3f2226/azure_cli_command_modules_nspkg-2.0.2-py2.py3-none-any.whl
# Collecting backports.weakref (from backports.tempfile->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting colorama>=0.3.9 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/4f/a6/728666f39bfff1719fc94c481890b2106837da9318031f71a8424b662e12/colorama-0.4.1-py2.py3-none-any.whl
# Collecting pyyaml>=4.2b1 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a8/c6/a8d1555e795dbd0375c3c93b576ca13bbf139db51ea604afa19a2c35fc03/PyYAML-4.2b4.tar.gz (262kB)
# Collecting argcomplete>=1.8.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/31/88/ba8d8684a8a27749250c66ff7c2b408fdbc29b50da61200338ff9b2607bf/argcomplete-1.9.4-py2.py3-none-any.whl
# Collecting pygments (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/13/e5/6d710c9cf96c31ac82657bcfb441df328b22df8564d58d0c4cd62612674c/Pygments-2.3.1-py2.py3-none-any.whl (849kB)
# Collecting pyopenssl>=17.1.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/96/af/9d29e6bd40823061aea2e0574ccb2fcf72bfd6130ce53d32773ec375458c/pyOpenSSL-18.0.0-py2.py3-none-any.whl (53kB)
# Collecting futures (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/cc/26/b61e3a4eb50653e8a7339d84eeaa46d1e93b92951978873c220ae64d0733/futures-3.1.1.tar.gz
# Collecting tabulate<=0.8.2,>=0.7.7 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/12/c2/11d6845db5edf1295bc08b2f488cf5937806586afe42936c3f34c097ebdc/tabulate-0.8.2.tar.gz (45kB)
# Collecting paramiko>=2.0.8 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/cf/ae/94e70d49044ccc234bfdba20114fa947d7ba6eb68a2e452d89b920e62227/paramiko-2.4.2-py2.py3-none-any.whl (193kB)
# Collecting jmespath (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting wheel==0.30.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/0c/80/16a85b47702a1f47a63c104c91abdd0a6704ee8ae3b4ce4afc49bc39f9d9/wheel-0.30.0-py2.py3-none-any.whl (49kB)
# Collecting antlr4-python3-runtime; python_version >= "3.0" (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/29/14/8ac135ec7cc9db3f768e2d032776718c6b23f74e63543f0974b4873500b2/antlr4-python3-runtime-4.7.2.tar.gz (112kB)
# Requirement already satisfied: pip in /azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib/python3.6/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1)) (18.1)
# Collecting azure-cli-nspkg>=2.0.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a7/85/601ef6484bf7a722daa76a4383c4ccfd4980b74ed6c2895392f53ed210d5/azure_cli_nspkg-3.0.3-py2.py3-none-any.whl
# Collecting humanfriendly>=4.7 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/79/1e/13d96248e3fcaa7777b61fa889feab44865c85e524bbd667acfa0d8b66e3/humanfriendly-4.17-py2.py3-none-any.whl (72kB)
# Collecting azure-cli-telemetry (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/71/4c/da5ebe9300ecdc850031372f81229383c46a70e83dee8e77f58aa6fd0546/azure_cli_telemetry-1.0.0-py2.py3-none-any.whl
# Collecting knack==0.5.1 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/46/0a6d7471efcc519e392640f6933c0f644bbf602971e64797108292cb3623/knack-0.5.1-py2.py3-none-any.whl (50kB)
# Collecting pyasn1>=0.1.1 (from ndg-httpsclient->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7b/7c/c9386b82a25115cccf1903441bba3cbadcfae7b678a20167347fa8ded34c/pyasn1-0.4.5-py2.py3-none-any.whl (73kB)
# Collecting pycparser (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b8/03/ec2be6c125f330361afe33bff48ef7549c47da8fefc658a2df2242175b4b/oauthlib-3.0.0-py2.py3-none-any.whl (142kB)
# Collecting bcrypt>=3.1.3 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d0/79/79a4d167a31cc206117d9b396926615fa9c1fdbd52017bcced80937ac501/bcrypt-3.1.6-cp34-abi3-manylinux1_x86_64.whl (55kB)
# Collecting pynacl>=1.0.1 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
# Collecting portalocker==1.2.1 (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults==1.0.2->-r /azureml-setup/condaenv.jl5uxr5a.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/57/41/05e79e5516db1cc0c967b3202388cde729f871c871b0a07bf24ff11adfcf/portalocker-1.2.1-py2.py3-none-any.whl
# Building wheels for collected packages: SecretStorage, pathspec, pyyaml, futures, tabulate, antlr4-python3-runtime, pycparser
#   Running setup.py bdist_wheel for SecretStorage: started
#   Running setup.py bdist_wheel for SecretStorage: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/4e/5b/1b/be8c8a830a0243af85b2946a0aece2c6743d7f7f946977ed67
#   Running setup.py bdist_wheel for pathspec: started
#   Running setup.py bdist_wheel for pathspec: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/45/cb/7e/ce6e6062c69446e39e328170524ca8213498bc66a74c6a210b
#   Running setup.py bdist_wheel for pyyaml: started
#   Running setup.py bdist_wheel for pyyaml: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/d2/ab/e6/df7b6c9e3b43272fe0164d6a012e4e02e63baaddae4ca6a0d0
#   Running setup.py bdist_wheel for futures: started
#   Running setup.py bdist_wheel for futures: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/f3/f9/c7/4fbf1faa6038faf183f6e3ea61f17a5f7eea5ab9a1dd7753fd
#   Running setup.py bdist_wheel for tabulate: started
#   Running setup.py bdist_wheel for tabulate: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/2a/85/33/2f6da85d5f10614cbe5a625eab3b3aebfdf43e7b857f25f829
#   Running setup.py bdist_wheel for antlr4-python3-runtime: started
#   Running setup.py bdist_wheel for antlr4-python3-runtime: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/03/65/47/b6700d23b7529a49513f7601b4f96174a4fa9efdbec03e7ea3
#   Running setup.py bdist_wheel for pycparser: started
#   Running setup.py bdist_wheel for pycparser: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built SecretStorage pathspec pyyaml futures tabulate antlr4-python3-runtime pycparser
# azure-cli-core 2.0.55 has requirement azure-mgmt-resource==2.0.0, but you'll have azure-mgmt-resource 2.1.0 which is incompatible.
# Installing collected packages: applicationinsights, azure-common, azure-nspkg, azure-storage-nspkg, oauthlib, chardet, idna, urllib3, requests, requests-oauthlib, isodate, msrest, pycparser, cffi, asn1crypto, cryptography, PyJWT, adal, msrestazure, azure-mgmt-resource, azure-mgmt-storage, azure-mgmt-authorization, websocket-client, docker-pycreds, docker, azure-graphrbac, azure-mgmt-containerregistry, azure-storage-common, azure-mgmt-nspkg, azure-mgmt-keyvault, azure-cli-nspkg, azure-cli-command-modules-nspkg, colorama, pyyaml, argcomplete, pygments, pyopenssl, futures, tabulate, pyasn1, bcrypt, pynacl, paramiko, jmespath, wheel, antlr4-python3-runtime, humanfriendly, portalocker, azure-cli-telemetry, knack, azure-cli-core, azure-cli-profile, jsonpickle, backports.weakref, backports.tempfile, SecretStorage, ruamel.yaml, ndg-httpsclient, pathspec, azure-storage-blob, contextlib2, azureml-core, azureml-defaults
#   Found existing installation: wheel 0.32.3
#     Uninstalling wheel-0.32.3:
#       Successfully uninstalled wheel-0.32.3
# Successfully installed PyJWT-1.7.1 SecretStorage-2.3.1 adal-1.2.0 antlr4-python3-runtime-4.7.2 applicationinsights-0.11.7 argcomplete-1.9.4 asn1crypto-0.24.0 azure-cli-command-modules-nspkg-2.0.2 azure-cli-core-2.0.55 azure-cli-nspkg-3.0.3 azure-cli-profile-2.1.2 azure-cli-telemetry-1.0.0 azure-common-1.1.17 azure-graphrbac-0.53.0 azure-mgmt-authorization-0.51.1 azure-mgmt-containerregistry-2.6.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-resource-2.1.0 azure-mgmt-storage-3.1.1 azure-nspkg-3.0.2 azure-storage-blob-1.4.0 azure-storage-common-1.4.0 azure-storage-nspkg-3.1.0 azureml-core-1.0.2 azureml-defaults-1.0.2 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.1.6 cffi-1.11.5 chardet-3.0.4 colorama-0.4.1 contextlib2-0.5.5 cryptography-2.4.2 docker-3.7.0 docker-pycreds-0.4.0 futures-3.1.1 humanfriendly-4.17 idna-2.8 isodate-0.6.0 jmespath-0.9.3 jsonpickle-1.0 knack-0.5.1 msrest-0.6.4 msrestazure-0.6.0 ndg-httpsclient-0.5.1 oauthlib-3.0.0 paramiko-2.4.2 pathspec-0.5.9 portalocker-1.2.1 pyasn1-0.4.5 pycparser-2.19 pygments-2.3.1 pynacl-1.3.0 pyopenssl-18.0.0 pyyaml-4.2b4 requests-2.21.0 requests-oauthlib-1.2.0 ruamel.yaml-0.15.51 tabulate-0.8.2 urllib3-1.23 websocket-client-0.54.0 wheel-0.30.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
# Removing intermediate container c3d3fba617d8
#  ---> f7820c29a9e7
# Step 9/12 : ENV PATH /azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/bin:$PATH
#  ---> Running in 51d2e73c2785
# Removing intermediate container 51d2e73c2785
#  ---> c978a80f9f88
# Step 10/12 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib:$LD_LIBRARY_PATH
#  ---> Running in afd7c1ea4004
# Removing intermediate container afd7c1ea4004
#  ---> 967c324278f4
# Step 11/12 : COPY azureml-setup/spark_cache.py azureml-setup/log4j.properties /azureml-setup/
#  ---> 2742e547824c
# Step 12/12 : CMD ["bash"]
#  ---> Running in 9942c6e7c65f
# Removing intermediate container 9942c6e7c65f
#  ---> a76b1dd4bce3
# Successfully built a76b1dd4bce3
# Successfully tagged pekamlws1688522486.azurecr.io/azureml/azureml_f98b091aecd4899163ce167f23345a55:latest
# 2019/01/21 07:32:12 Successfully executed container: acb_step_0
# 2019/01/21 07:32:12 Executing step ID: acb_step_1. Working directory: '', Network: 'acb_default_network'
# 2019/01/21 07:32:12 Pushing image: pekamlws1688522486.azurecr.io/azureml/azureml_f98b091aecd4899163ce167f23345a55:latest, attempt 1
# The push refers to repository [pekamlws1688522486.azurecr.io/azureml/azureml_f98b091aecd4899163ce167f23345a55]
# 9b60cdfe479c: Preparing
# 61a71c5e8f34: Preparing
# 1ba9d26d09cd: Preparing
# 3fbac8b7eb95: Preparing
# 904a38f3154c: Preparing
# e7ff3c8d56c2: Preparing
# ce619be2681d: Preparing
# db9d63ec4abf: Preparing
# 2fc9fc8da07e: Preparing
# 150ddd7a1544: Preparing
# 75b79e19929c: Preparing
# 4775b2f378bb: Preparing
# 883eafdbe580: Preparing
# 19d043c86cbc: Preparing
# 8823818c4748: Preparing
# e7ff3c8d56c2: Waiting
# ce619be2681d: Waiting
# db9d63ec4abf: Waiting
# 2fc9fc8da07e: Waiting
# 150ddd7a1544: Waiting
# 75b79e19929c: Waiting
# 4775b2f378bb: Waiting
# 883eafdbe580: Waiting
# 19d043c86cbc: Waiting
# 8823818c4748: Waiting
# 904a38f3154c: Pushed
# 1ba9d26d09cd: Pushed
# 9b60cdfe479c: Pushed
# 3fbac8b7eb95: Pushed
# ce619be2681d: Pushed
# e7ff3c8d56c2: Pushed
# 2fc9fc8da07e: Pushed
# 150ddd7a1544: Pushed
# 75b79e19929c: Pushed
# 4775b2f378bb: Pushed
# 883eafdbe580: Pushed
# 19d043c86cbc: Pushed
# 8823818c4748: Pushed
# db9d63ec4abf: Pushed
# 61a71c5e8f34: Pushed
# latest: digest: sha256:147261707b69b121026b06cfba680f53bd89114ed2174a282c3203d4c5e542e0 size: 3458
# 2019/01/21 07:34:30 Successfully pushed image: pekamlws1688522486.azurecr.io/azureml/azureml_f98b091aecd4899163ce167f23345a55:latest
# 2019/01/21 07:34:30 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 162.124910)
# 2019/01/21 07:34:30 Populating digests for step ID: acb_step_0...
# 2019/01/21 07:34:32 Successfully populated digests for step ID: acb_step_0
# 2019/01/21 07:34:32 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 138.000107)
# 2019/01/21 07:34:32 The following dependencies were found:
# 2019/01/21 07:34:32
# - image:
#     registry: pekamlws1688522486.azurecr.io
#     repository: azureml/azureml_f98b091aecd4899163ce167f23345a55
#     tag: latest
#     digest: sha256:147261707b69b121026b06cfba680f53bd89114ed2174a282c3203d4c5e542e0
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: 0.2.0
#     digest: sha256:bddfac8e9a4406c13f314cefefa24f3f67e959a8d8b26067096f7ade6f02ef12
#   git: {}
#
# Run ID: cm2 was successful after 5m7s
#
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# Streaming log file azureml-logs/60_control_log.txt
# Streaming log file azureml-logs/80_driver_log.txt
#
# Streaming azureml-logs/80_driver_log.txt
# ========================================
#
#
#
# The experiment failed. Finalizing run...
# Logging experiment finalizing status in history service
# Traceback (most recent call last):
#   File "azureml-setup/context_manager_injector.py", line 88, in execute_with_context
#     runpy.run_path(sys.argv[0], globals(), run_name="__main__")
#   File "/azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib/python3.6/runpy.py", line 261, in run_path
#     code, fname = _get_code_from_file(run_name, path_name)
#   File "/azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib/python3.6/runpy.py", line 236, in _get_code_from_file
#     code = compile(f.read(), fname, 'exec')
#   File "train.py", line 53
#     run.log('FeatureImportance', result.)
#                                         ^
# SyntaxError: invalid syntax
#
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 1 items cleaning up...
# Cleanup took 0.10093975067138672 seconds
# Traceback (most recent call last):
#   File "azureml-setup/context_manager_injector.py", line 152, in <module>
#     execute_with_context(cm_objects, options.invocation)
#   File "azureml-setup/context_manager_injector.py", line 88, in execute_with_context
#     runpy.run_path(sys.argv[0], globals(), run_name="__main__")
#   File "/azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib/python3.6/runpy.py", line 261, in run_path
#     code, fname = _get_code_from_file(run_name, path_name)
#   File "/azureml-envs/azureml_bf48ffd73fa93a5aff041729098be978/lib/python3.6/runpy.py", line 236, in _get_code_from_file
#     code = compile(f.read(), fname, 'exec')
#   File "train.py", line 53
#     run.log('FeatureImportance', result.)
#                                         ^
# SyntaxError: invalid syntax
# Execution Summary
# =================
# RunId: c4ts-customlib_1548055757348
#
# Wall time: 14min 28s
# {'runId': 'c4ts-customlib_1548055757348',
#  'target': 'pekamlcompute',
#  'status': 'Failed',
#  'startTimeUtc': '2019-01-21T07:39:49.858093Z',
#  'endTimeUtc': '2019-01-21T07:43:52.096486Z',
#  'properties': {'azureml.runsource': 'experiment',
#   'ContentSnapshotId': '87181bd7-5911-4c64-b749-6526f1bed5ed'},
#  'runDefinition': {'Script': 'train.py',
#   'Arguments': [],
#   'SourceDirectoryDataStore': None,
#   'Framework': 0,
#   'Communicator': 0,
#   'Target': 'pekamlcompute',
#   'DataReferences': {},
#   'JobName': None,
#   'AutoPrepareEnvironment': True,
#   'MaxRunDurationSeconds': None,
#   'NodeCount': 1,
#   'Environment': {'Python': {'InterpreterPath': 'python',
#     'UserManagedDependencies': False,
#     'CondaDependencies': {'name': 'project_environment',
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults==1.0.2']},
#       'scikit-learn',
#       'pandas',
#       'numpy']}},
#    'EnvironmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'Docker': {'BaseImage': 'mcr.microsoft.com/azureml/base:0.2.0',
#     'Enabled': True,
#     'SharedVolumes': True,
#     'Preparation': None,
#     'GpuSupport': False,
#     'ShmSize': '1g',
#     'Arguments': [],
#     'BaseImageRegistry': {'Address': None,
#      'Username': None,
#      'Password': None}},
#    'Spark': {'Repositories': ['https://mmlspark.azureedge.net/maven'],
#     'Packages': [{'Group': 'com.microsoft.ml.spark',
#       'Artifact': 'mmlspark_2.11',
#       'Version': '0.12'}],
#     'PrecachePackages': True}},
#   'History': {'OutputCollection': True},
#   'Spark': {'Configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'BatchAi': {'NodeCount': 0},
#   'AmlCompute': {'Name': None,
#    'VmSize': None,
#    'VmPriority': None,
#    'RetainCluster': False,
#    'ClusterMaxNodeCount': 1},
#   'Tensorflow': {'WorkerCount': 1, 'ParameterServerCount': 1},
#   'Mpi': {'ProcessCountPerNode': 1},
#   'Hdi': {'YarnDeployMode': 2},
#   'ContainerInstance': {'Region': None, 'CpuCores': 0, 'MemoryGb': 0},
#   'ExposedPorts': None,
#   'PrepareEnvironment': None},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://pekamlws9494799492.blob.core.windows.net/azureml/ExperimentRun/dcid.c4ts-customlib_1548055757348/azureml-logs/20_image_build_log.txt?sv=2018-03-28&sr=b&sig=zJsZ2YpTfnd4PwC4wn3GMQfFPfGzbJX0Ua5xZRXIVZI%3D&st=2019-01-21T07%3A33%3A53Z&se=2019-01-21T15%3A43%3A53Z&sp=r',
#   'azureml-logs/60_control_log.txt': 'https://pekamlws9494799492.blob.core.windows.net/azureml/ExperimentRun/dcid.c4ts-customlib_1548055757348/azureml-logs/60_control_log.txt?sv=2018-03-28&sr=b&sig=uVQoAK5Oqu2DTfpcFG1UDjOchoouHWJJu%2BIshKS%2BXFU%3D&st=2019-01-21T07%3A33%3A53Z&se=2019-01-21T15%3A43%3A53Z&sp=r',
#   'azureml-logs/azureml.log': 'https://pekamlws9494799492.blob.core.windows.net/azureml/ExperimentRun/dcid.c4ts-customlib_1548055757348/azureml-logs/azureml.log?sv=2018-03-28&sr=b&sig=bZMoCG8b1%2FLyCaxuspfnJicJhdVpydfi8Eo3rpoUf18%3D&st=2019-01-21T07%3A33%3A53Z&se=2019-01-21T15%3A43%3A53Z&sp=r',
#   'azureml-logs/80_driver_log.txt': 'https://pekamlws9494799492.blob.core.windows.net/azureml/ExperimentRun/dcid.c4ts-customlib_1548055757348/azureml-logs/80_driver_log.txt?sv=2018-03-28&sr=b&sig=sq1gd%2BxhpEFTz0a7lumFuGpzCvvXl%2BcsAPmUfuTZupU%3D&st=2019-01-21T07%3A33%3A53Z&se=2019-01-21T15%3A43%3A53Z&sp=r',
#   'azureml-logs/56_batchai_stderr.txt': 'https://pekamlws9494799492.blob.core.windows.net/azureml/ExperimentRun/dcid.c4ts-customlib_1548055757348/azureml-logs/56_batchai_stderr.txt?sv=2018-03-28&sr=b&sig=n05qp5SGFaco%2FQ6cZn84YH8bsjx%2BdbDA7rC%2F%2FraPchM%3D&st=2019-01-21T07%3A33%3A53Z&se=2019-01-21T15%3A43%3A53Z&sp=r',
#   'azureml-logs/55_batchai_execution.txt': 'https://pekamlws9494799492.blob.core.windows.net/azureml/ExperimentRun/dcid.c4ts-customlib_1548055757348/azureml-logs/55_batchai_execution.txt?sv=2018-03-28&sr=b&sig=NCAm30wcueMllCIxnf5eG4AD8ERtyvz%2FyAErS7AsDRU%3D&st=2019-01-21T07%3A33%3A53Z&se=2019-01-21T15%3A43%3A53Z&sp=r'}}

# %%
run.get_metrics()
# Out:
# {}
